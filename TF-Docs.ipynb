# %%
import json
import tensorflow as tf

import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import io
import re

# %%
def json_to_dict(file):
    diction= open(file)
    return json.load(diction)

def plain_to_dict(file):
    f= open(file, encoding="utf8")
    return json.load(f)

def clean_text(rgx_list, text):
    new_text = text.lower()
    for rgx_match in rgx_list:
        new_text = re.sub(rgx_match, '', new_text)   
    return new_text

# %%
#Geology
geo1= json_to_dict('geologic_processes.json')
geo2= plain_to_dict('age_of_earth')
#Paleontolgy
paleo= plain_to_dict('paleontology.json')
#Cosmology
cosmo= plain_to_dict('cosmology')
#Ecology
eco= plain_to_dict('ecology_conservation')
#Faith and science
faith= plain_to_dict('faith_and_science')
#Intelligent desgin
design= plain_to_dict('inteligentDesign.json')
#Biology
bio= plain_to_dict('Biology.json')
#Other sciences

#Join Geo
geo= {"geology": list(geo1.values())[0]+list(geo2.values())[0]}

#all_data= plain_to_dict('allDataset.json')

# %%
all_data= {
            'geology': geo,
            'paleontology': paleo,
            'cosmology': cosmo,
            'ecology': eco,
            'faith': faith,
            'design': design,
            'biology': bio
          }
#print(all_data)
#import json
with open('all_data.json', 'w') as fp:
    json.dump(all_data, fp)

# %%
all_arts= []
all_labels= []

for count,top in enumerate([geo,paleo,cosmo,eco,faith,design,bio]):
#for count,top in enumerate([all_data]):
    arts= []

    for art in list(top.values())[0][:30]:
        arts.append(art['doc'])
    labels= [count]*len(arts)
    
    all_arts.append(arts)
    all_labels.append(labels)
    #print(arts)
    #print(labels)


all_arts= [item for sublist in all_arts for item in sublist]
all_labels= [item for sublist in all_labels for item in sublist]

patterns= [r'[\t\n\r\f\v\d]', r'(.+doi.+(Summary\. ?|\n)|.+DOI.+(Summary\. ?|\n))',
           r'\[[\w\.;,\- ]+\]', r'\([\w\.;,\- ]+\)'#, r'“[\w+]”', r'[\w+]”', r'“[\w+]',
           r'[F|f]ig[\.\w]+ [\w,\- ]+|see [F|f]ig[\.\w]+ [\w,\- ]+',# r'[\"]',
           r'[.,\/#!$%\^&\*;:{}=\-\[\]_`~()“”…—\"\"‘’\'\'>–]',# r'[\']',r'[\’]',
           r'WHAT THIS ARTICLE IS ABOUT|ABSTRACT|INTRODUCTION|ACKNOWLEDGMENTS?|CONCLUSIONS?|Conclusions?|SUMMARY|DISCUSSION|Geoscience Research Institute',
           #r'\bthe\b',r'\bof\b',r'\bin\b',r'\bare\b',r'\bthe[m|y]\b',r'\bi(s|f|t)\b',r'\ba(n|ll|nd|t)?\b',r'\bto\b',r'\bwhich\b',r'\bby\b',
           #r'\bf?or\b',r'\bthose\b',r'\bfrom\b',r'\bto\b',r'\bbut\b',r'\bmuch\b',r'\bthese\b',r'\bthere\b',r'\bwith\b',r'\xa0',
           r'\bthese\b',r'\bthere\b',r'\bwhich\b',r'\xa0',
           r'\b\w{,5}\b',r'\b\w{18,}\b']

all_cleaned= []
for art in all_arts:
    art= re.split('ENDNOTES|Endnotes|REFERENCES|References|Footnotes|FOR FURTHER STUDY|LITERATURE CITED', art)[0]
    #art= clean_text(patterns, art)
    all_cleaned.append(clean_text(patterns, art))

# %%
re2= 'Dinosaaaur fossils at are –- them \"widespre\'ad \xa0all in ‘penn>sylvan-i’aeuringer layer—were'
new_text= re.sub(r'[.,\/#!$%\^&\*;:{}=\-\[\]_`~()“”…—\"\"‘’\'\'>–]', '', re2)
#new_text2= re.sub(r'\b\w{20,}\b', '', new_text)
print(re2)
print(new_text)
#print(new_text2)
#print(all_cleaned[0])
# Out:
# Dinosaaaur fossils at are –- them "widespre'ad  all in ‘penn>sylvan-i’aeuringer layer—were
# Dinosaaaur fossils at are  them widespread  all in pennsylvaniaeuringer layerwere

# %%
#Sets
x_train, x_test, y_train, y_test= train_test_split(all_cleaned, all_labels, test_size=0.25)

training_labels= np.array(y_train)
testing_labels= np.array(y_test)

# %%
#Variables
vocab_size= 10000
max_length= 32
trunc_type= "post"
padding_type= "post"
oov_tok= "<OOV>"

#Tokenize
tokenizer= Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(x_train)
word_index= tokenizer.word_index

#Train sentences
training_sequences= tokenizer.texts_to_sequences(x_train)
training_padded= pad_sequences(training_sequences, maxlen=max_length,
                               padding=padding_type, truncating=trunc_type)

#Test sentences
testing_sequences= tokenizer.texts_to_sequences(x_test)
testing_padded= pad_sequences(testing_sequences, maxlen=max_length, 
                              padding=padding_type, truncating=trunc_type)

# %%
embedding_dim= 16

#Keras model
model= tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 32, 16)            160000
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                408
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 160,433
# Trainable params: 160,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train
num_epochs= 30

history= model.fit(training_padded, training_labels, epochs=num_epochs,
                   validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Train on 125 samples, validate on 42 samples
# Epoch 1/30
# 125/125 - 1s - loss: 0.6701 - accuracy: 0.1760 - val_loss: 0.6385 - val_accuracy: 0.1667
# Epoch 2/30
# 125/125 - 0s - loss: 0.6177 - accuracy: 0.1840 - val_loss: 0.5862 - val_accuracy: 0.1667
# Epoch 3/30
# 125/125 - 0s - loss: 0.5572 - accuracy: 0.1840 - val_loss: 0.5291 - val_accuracy: 0.1667
# Epoch 4/30
# 125/125 - 0s - loss: 0.4926 - accuracy: 0.1840 - val_loss: 0.4672 - val_accuracy: 0.1667
# Epoch 5/30
# 125/125 - 0s - loss: 0.4213 - accuracy: 0.1840 - val_loss: 0.4015 - val_accuracy: 0.1667
# Epoch 6/30
# 125/125 - 0s - loss: 0.3442 - accuracy: 0.1840 - val_loss: 0.3315 - val_accuracy: 0.1667
# Epoch 7/30
# 125/125 - 0s - loss: 0.2656 - accuracy: 0.1840 - val_loss: 0.2564 - val_accuracy: 0.1667
# Epoch 8/30
# 125/125 - 0s - loss: 0.1756 - accuracy: 0.1840 - val_loss: 0.1763 - val_accuracy: 0.1667
# Epoch 9/30
# 125/125 - 0s - loss: 0.0782 - accuracy: 0.1840 - val_loss: 0.0906 - val_accuracy: 0.1667
# Epoch 10/30
# 125/125 - 0s - loss: -2.1786e-02 - accuracy: 0.1840 - val_loss: -2.4068e-03 - val_accuracy: 0.1667
# Epoch 11/30
# 125/125 - 0s - loss: -1.3389e-01 - accuracy: 0.1840 - val_loss: -1.0315e-01 - val_accuracy: 0.1667
# Epoch 12/30
# 125/125 - 0s - loss: -2.5633e-01 - accuracy: 0.1840 - val_loss: -2.1181e-01 - val_accuracy: 0.1667
# Epoch 13/30
# 125/125 - 0s - loss: -3.9293e-01 - accuracy: 0.1840 - val_loss: -3.2835e-01 - val_accuracy: 0.1667
# Epoch 14/30
# 125/125 - 0s - loss: -5.2952e-01 - accuracy: 0.1840 - val_loss: -4.5555e-01 - val_accuracy: 0.1667
# Epoch 15/30
# 125/125 - 0s - loss: -6.9516e-01 - accuracy: 0.1840 - val_loss: -5.9081e-01 - val_accuracy: 0.1667
# Epoch 16/30
# 125/125 - 0s - loss: -8.6109e-01 - accuracy: 0.1840 - val_loss: -7.3738e-01 - val_accuracy: 0.1667
# Epoch 17/30
# 125/125 - 0s - loss: -1.0426e+00 - accuracy: 0.1840 - val_loss: -8.9456e-01 - val_accuracy: 0.1667
# Epoch 18/30
# 125/125 - 0s - loss: -1.2535e+00 - accuracy: 0.1840 - val_loss: -1.0608e+00 - val_accuracy: 0.1667
# Epoch 19/30
# 125/125 - 0s - loss: -1.4568e+00 - accuracy: 0.1840 - val_loss: -1.2427e+00 - val_accuracy: 0.1667
# Epoch 20/30
# 125/125 - 0s - loss: -1.6871e+00 - accuracy: 0.1840 - val_loss: -1.4356e+00 - val_accuracy: 0.1667
# Epoch 21/30
# 125/125 - 0s - loss: -1.9418e+00 - accuracy: 0.1840 - val_loss: -1.6395e+00 - val_accuracy: 0.1667
# Epoch 22/30
# 125/125 - 0s - loss: -2.1939e+00 - accuracy: 0.1840 - val_loss: -1.8581e+00 - val_accuracy: 0.1667
# Epoch 23/30
# 125/125 - 0s - loss: -2.4722e+00 - accuracy: 0.1840 - val_loss: -2.0898e+00 - val_accuracy: 0.1667
# Epoch 24/30
# 125/125 - 0s - loss: -2.7785e+00 - accuracy: 0.1840 - val_loss: -2.3325e+00 - val_accuracy: 0.1667
# Epoch 25/30
# 125/125 - 0s - loss: -3.1044e+00 - accuracy: 0.1840 - val_loss: -2.5863e+00 - val_accuracy: 0.1667
# Epoch 26/30
# 125/125 - 0s - loss: -3.4373e+00 - accuracy: 0.1840 - val_loss: -2.8561e+00 - val_accuracy: 0.1667
# Epoch 27/30
# 125/125 - 0s - loss: -3.7833e+00 - accuracy: 0.1840 - val_loss: -3.1417e+00 - val_accuracy: 0.1667
# Epoch 28/30
# 125/125 - 0s - loss: -4.1630e+00 - accuracy: 0.1840 - val_loss: -3.4404e+00 - val_accuracy: 0.1667
# Epoch 29/30
# 125/125 - 0s - loss: -4.5554e+00 - accuracy: 0.1840 - val_loss: -3.7553e+00 - val_accuracy: 0.1667
# Epoch 30/30
# 125/125 - 0s - loss: -4.9745e+00 - accuracy: 0.1840 - val_loss: -4.0845e+00 - val_accuracy: 0.1667

# %%
e= model.layers[0]
weights= e.get_weights()[0]
print(weights.shape)
# Out:
# (10000, 16)

# %%
rev_vocab= dict([(value,key) for (key,value) in word_index.items()])
print(rev_vocab)
# Out:
# {1: '<OOV>', 2: 'creation', 3: 'genesis', 4: 'between', 5: 'biblical', 6: 'different', 7: 'nature', 8: 'evidence', 9: 'animals', 10: 'because', 11: 'fossil', 12: 'species', 13: 'should', 14: 'however', 15: 'similar', 16: 'design', 17: 'universe', 18: 'fossils', 19: 'through', 20: 'record', 21: 'living', 22: 'organisms', 23: 'second', 24: 'created', 25: 'humans', 26: 'narrative', 27: 'example', 28: 'account', 29: 'several', 30: 'information', 31: 'before', 32: 'hebrew', 33: 'system', 34: 'theory', 35: 'science', 36: 'testament', 37: 'another', 38: 'present', 39: 'number', 40: 'scientific', 41: 'modern', 42: 'during', 43: 'natural', 44: 'history', 45: 'within', 46: 'appears', 47: 'formation', 48: 'possible', 49: 'called', 50: 'result', 51: 'origin', 52: 'argument', 53: 'cambrian', 54: 'waters', 55: 'ancient', 56: 'structure', 57: 'important', 58: 'rather', 59: 'changes', 60: 'appear', 61: 'evolutionary', 62: 'common', 63: 'section', 64: 'meaning', 65: 'things', 66: 'preservation', 67: 'universal', 68: 'explain', 69: 'thought', 70: 'without', 71: 'material', 72: 'earths', 73: 'formed', 74: 'elements', 75: 'question', 76: 'literary', 77: 'recent', 78: 'evolution', 79: 'original', 80: 'genetic', 81: 'although', 82: 'problem', 83: 'hypothesis', 84: 'suggested', 85: 'source', 86: 'according', 87: 'existence', 88: 'patterns', 89: 'planet', 90: 'millions', 91: 'globin', 92: 'differences', 93: 'standard', 94: 'therefore', 95: 'surface', 96: 'scientists', 97: 'remains', 98: 'process', 99: 'carbon', 100: 'research', 101: 'described', 102: 'passages', 103: 'geologic', 104: 'energy', 105: 'phrase', 106: 'complex', 107: 'believe', 108: 'change', 109: 'studies', 110: 'features', 111: 'creator', 112: 'significant', 113: 'animal', 114: 'examples', 115: 'function', 116: 'beginning', 117: 'precambrian', 118: 'including', 119: 'cannot', 120: 'statement', 121: 'observed', 122: 'processes', 123: 'expression', 124: 'preserved', 125: 'divine', 126: 'intelligent', 127: 'occurred', 128: 'explanation', 129: 'probably', 130: 'statements', 131: 'sequence', 132: 'matter', 133: 'further', 134: 'groups', 135: 'context', 136: 'certain', 137: 'pattern', 138: 'related', 139: 'something', 140: 'sources', 141: 'environment', 142: 'sequences', 143: 'understanding', 144: 'necessary', 145: 'dinosaur', 146: 'whether', 147: 'others', 148: 'together', 149: 'people', 150: 'christian', 151: 'planets', 152: 'banding', 153: 'literature', 154: 'geological', 155: 'deposits', 156: 'around', 157: 'provide', 158: 'general', 159: 'little', 160: 'century', 161: 'chapter', 162: 'chemical', 163: 'heaven', 164: 'impact', 165: 'chromosomal', 166: 'considered', 167: 'perhaps', 168: 'various', 169: 'ground', 170: 'christians', 171: 'family', 172: 'specific', 173: 'written', 174: 'layers', 175: 'atmosphere', 176: 'million', 177: 'events', 178: 'global', 179: 'creatures', 180: 'sections', 181: 'article', 182: 'interpretation', 183: 'designed', 184: 'suggest', 185: 'expected', 186: 'analysis', 187: 'include', 188: 'biological', 189: 'suggests', 190: 'period', 191: 'beings', 192: 'sabbath', 193: 'mutations', 194: 'against', 195: 'conditions', 196: 'theological', 197: 'interpreted', 198: 'development', 199: 'special', 200: 'clearly', 201: 'plants', 202: 'paleozoic', 203: 'either', 204: 'provides', 205: 'entire', 206: 'reason', 207: 'physical', 208: 'passage', 209: 'isaiah', 210: 'selection', 211: 'pseudogene', 212: 'involved', 213: 'already', 214: 'oxygen', 215: 'picture', 216: 'similarities', 217: 'questions', 218: 'discussion', 219: 'conclusion', 220: 'compared', 221: 'environmental', 222: 'especially', 223: 'produce', 224: 'proteins', 225: 'published', 226: 'protein', 227: 'chromosomes', 228: 'neanderthals', 229: 'caused', 230: 'itself', 231: 'description', 232: 'refers', 233: 'historical', 234: 'reference', 235: 'points', 236: 'presence', 237: 'systems', 238: 'chronology', 239: 'indicate', 240: 'results', 241: 'volcanic', 242: 'marine', 243: 'atrahasis', 244: 'following', 245: 'actually' ...

# %%
#TSV
out_v= io.open('vecs.tsv', 'w', encoding='utf-8')
out_m= io.open('meta.tsv', 'w', encoding='utf-8')

for word_num in range(1, vocab_size):
    word= rev_vocab[word_num]
    embeddings= weights[word_num]
    out_m.write(word + "\n")
    out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")

out_v.close()
out_m.close()

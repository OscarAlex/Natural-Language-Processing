# %%
import json
import tensorflow as tf

import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import io
import re

# %%
def json_to_dict(file):
    diction= open(file)
    return json.load(diction)

def plain_to_dict(file):
    f= open(file, encoding="utf8")
    return json.load(f)

#Geology
geo1= json_to_dict('geologic_processes.json')
geo2= plain_to_dict('age_of_earth')
#Paleontolgy
paleo= plain_to_dict('paleontology.json')
#Cosmology
cosmo= plain_to_dict('cosmology')
#Ecology
eco= plain_to_dict('ecology_conservation')
#Faith and science
faith= plain_to_dict('faith_and_science')
#Intelligent desgin
design= plain_to_dict('inteligentDesign.json')
#Biology
bio= json_to_dict('Biology.json')
#Other sciences

#Join Geo
geo= {"geology": list(geo1.values())[0]+list(geo2.values())[0]}

# %%
def clean_text(rgx_list, text):
    new_text = text.lower()
    for rgx_match in rgx_list:
        new_text = re.sub(rgx_match, '', new_text)   
    return new_text

all_arts= []
all_labels= []

for count,top in enumerate([geo,paleo,cosmo,eco,faith,design]):
    arts= []

    for art in list(top.values())[0][:30]:
        arts.append(art['doc'])
    labels= [count]*len(arts)
    
    all_arts.append(arts)
    all_labels.append(labels)
    #print(arts)
    #print(labels)


all_arts= [item for sublist in all_arts for item in sublist]
all_labels= [item for sublist in all_labels for item in sublist]

patterns= [r'[\t\n\r\f\v\d]', r'(.+doi.+(Summary\. ?|\n)|.+DOI.+(Summary\. ?|\n))',
           r'\[[\w\.;,\- ]+\]', r'\([\w\.;,\- ]+\)', r'“[\w+]”', r'[\w+]”', r'“[\w+]',
           r'[F|f]ig[\.\w]+ [\w,\- ]+|see [F|f]ig[\.\w]+ [\w,\- ]+', r'[\"]',
           r'[.,\/#!$%\^&\*;:{}=\-\[\]_`~()“”]', r'[\']',r'[\’]',
           r'WHAT THIS ARTICLE IS ABOUT|ABSTRACT|INTRODUCTION|ACKNOWLEDGMENTS?|CONCLUSIONS?|Conclusions?|SUMMARY|DISCUSSION|Geoscience Research Institute',
           r'\bthe\b',r'\bof\b',r'\bin\b',r'\bare\b',r'\bthe[m|y]\b',r'\bi(s|f|t)\b',r'\ba(n|ll|nd|t)?\b',r'\bto\b',r'\bwhich\b',r'\bby\b',
           r'\bf?or\b',r'\bthose\b',r'\bfrom\b',r'\bto\b',r'\bbut\b',r'\bthese\b',r'>',r'\bwith\b',r'\xa0']

all_cleaned= []
for art in all_arts:
    art= re.split('ENDNOTES|Endnotes|REFERENCES|References|Footnotes|FOR FURTHER STUDY|LITERATURE CITED', art)[0]
    #art= clean_text(patterns, art)
    all_cleaned.append(clean_text(patterns, art))

# %%
re2= 'Dinosaaaur fossils at are them \"widespread \xa0all in they and Mesozoic a ladf inimaginable'
new_text= re.sub(r'[\"]', '', re2)
print(re2)
print(new_text)
#print(all_cleaned[0])
# Out:
# Dinosaaaur fossils at are them "widespread  all in they and Mesozoic a ladf inimaginable
# Dinosaaaur fossils at are them widespread  all in they and Mesozoic a ladf inimaginable

# %%
#Sets
x_train, x_test, y_train, y_test= train_test_split(all_cleaned, all_labels, test_size=0.25)

training_labels= np.array(y_train)
testing_labels= np.array(y_test)

# %%
#Variables
vocab_size= 10000
max_length= 32
trunc_type= "post"
padding_type= "post"
oov_tok= "<OOV>"

#Tokenize
tokenizer= Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(x_train)
word_index= tokenizer.word_index

#Train sentences
training_sequences= tokenizer.texts_to_sequences(x_train)
training_padded= pad_sequences(training_sequences, maxlen=max_length,
                               padding=padding_type, truncating=trunc_type)

#Test sentences
testing_sequences= tokenizer.texts_to_sequences(x_test)
testing_padded= pad_sequences(testing_sequences, maxlen=max_length, 
                              padding=padding_type, truncating=trunc_type)

# %%
embedding_dim= 16

#Keras model
model= tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 32, 16)            160000
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                408
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 160,433
# Trainable params: 160,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train
num_epochs= 30

history= model.fit(training_padded, training_labels, epochs=num_epochs,
                   validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Train on 102 samples, validate on 35 samples
# Epoch 1/30
# 102/102 - 1s - loss: 0.6926 - accuracy: 0.2353 - val_loss: 0.6649 - val_accuracy: 0.1429
# Epoch 2/30
# 102/102 - 0s - loss: 0.6607 - accuracy: 0.2451 - val_loss: 0.6326 - val_accuracy: 0.1429
# Epoch 3/30
# 102/102 - 0s - loss: 0.6339 - accuracy: 0.2451 - val_loss: 0.5997 - val_accuracy: 0.1429
# Epoch 4/30
# 102/102 - 0s - loss: 0.6037 - accuracy: 0.2451 - val_loss: 0.5650 - val_accuracy: 0.1429
# Epoch 5/30
# 102/102 - 0s - loss: 0.5724 - accuracy: 0.2451 - val_loss: 0.5278 - val_accuracy: 0.1429
# Epoch 6/30
# 102/102 - 0s - loss: 0.5387 - accuracy: 0.2451 - val_loss: 0.4883 - val_accuracy: 0.1429
# Epoch 7/30
# 102/102 - 0s - loss: 0.5014 - accuracy: 0.2451 - val_loss: 0.4462 - val_accuracy: 0.1429
# Epoch 8/30
# 102/102 - 0s - loss: 0.4638 - accuracy: 0.2451 - val_loss: 0.4006 - val_accuracy: 0.1429
# Epoch 9/30
# 102/102 - 0s - loss: 0.4203 - accuracy: 0.2451 - val_loss: 0.3524 - val_accuracy: 0.1429
# Epoch 10/30
# 102/102 - 0s - loss: 0.3754 - accuracy: 0.2451 - val_loss: 0.3006 - val_accuracy: 0.1429
# Epoch 11/30
# 102/102 - 0s - loss: 0.3286 - accuracy: 0.2451 - val_loss: 0.2446 - val_accuracy: 0.1429
# Epoch 12/30
# 102/102 - 0s - loss: 0.2772 - accuracy: 0.2451 - val_loss: 0.1840 - val_accuracy: 0.1429
# Epoch 13/30
# 102/102 - 0s - loss: 0.2183 - accuracy: 0.2451 - val_loss: 0.1205 - val_accuracy: 0.1429
# Epoch 14/30
# 102/102 - 0s - loss: 0.1578 - accuracy: 0.2451 - val_loss: 0.0537 - val_accuracy: 0.1429
# Epoch 15/30
# 102/102 - 0s - loss: 0.0949 - accuracy: 0.2451 - val_loss: -1.7873e-02 - val_accuracy: 0.1429
# Epoch 16/30
# 102/102 - 0s - loss: 0.0258 - accuracy: 0.2451 - val_loss: -9.5032e-02 - val_accuracy: 0.1429
# Epoch 17/30
# 102/102 - 0s - loss: -5.0593e-02 - accuracy: 0.2451 - val_loss: -1.7739e-01 - val_accuracy: 0.1429
# Epoch 18/30
# 102/102 - 0s - loss: -1.2691e-01 - accuracy: 0.2451 - val_loss: -2.7007e-01 - val_accuracy: 0.1429
# Epoch 19/30
# 102/102 - 0s - loss: -2.1532e-01 - accuracy: 0.2451 - val_loss: -3.6855e-01 - val_accuracy: 0.1429
# Epoch 20/30
# 102/102 - 0s - loss: -3.1326e-01 - accuracy: 0.2451 - val_loss: -4.7016e-01 - val_accuracy: 0.1429
# Epoch 21/30
# 102/102 - 0s - loss: -4.1368e-01 - accuracy: 0.2451 - val_loss: -5.7872e-01 - val_accuracy: 0.1429
# Epoch 22/30
# 102/102 - 0s - loss: -5.1572e-01 - accuracy: 0.2451 - val_loss: -6.9470e-01 - val_accuracy: 0.1429
# Epoch 23/30
# 102/102 - 0s - loss: -6.2987e-01 - accuracy: 0.2451 - val_loss: -8.1900e-01 - val_accuracy: 0.1429
# Epoch 24/30
# 102/102 - 0s - loss: -7.5309e-01 - accuracy: 0.2451 - val_loss: -9.5086e-01 - val_accuracy: 0.1429
# Epoch 25/30
# 102/102 - 0s - loss: -8.7583e-01 - accuracy: 0.2451 - val_loss: -1.0935e+00 - val_accuracy: 0.1429
# Epoch 26/30
# 102/102 - 0s - loss: -1.0102e+00 - accuracy: 0.2451 - val_loss: -1.2369e+00 - val_accuracy: 0.1429
# Epoch 27/30
# 102/102 - 0s - loss: -1.1539e+00 - accuracy: 0.2451 - val_loss: -1.3852e+00 - val_accuracy: 0.1429
# Epoch 28/30
# 102/102 - 0s - loss: -1.3067e+00 - accuracy: 0.2451 - val_loss: -1.5467e+00 - val_accuracy: 0.1429
# Epoch 29/30
# 102/102 - 0s - loss: -1.4620e+00 - accuracy: 0.2451 - val_loss: -1.7233e+00 - val_accuracy: 0.1429
# Epoch 30/30
# 102/102 - 0s - loss: -1.6338e+00 - accuracy: 0.2451 - val_loss: -1.9047e+00 - val_accuracy: 0.1429

# %%
e= model.layers[0]
weights= e.get_weights()[0]
print(weights.shape)
# Out:
# (10000, 16)

# %%
rev_vocab= dict([(value,key) for (key,value) in word_index.items()])
print(rev_vocab)
# Out:
# {1: '<OOV>', 2: 'that', 3: 'this', 4: 'as', 5: 'be', 6: 'not', 7: 'on', 8: 'have', 9: 'was', 10: 'genesis', 11: 'creation', 12: 'we', 13: 'one', 14: 'has', 15: 'god', 16: 'earth', 17: 'can', 18: 'there', 19: 'would', 20: 'flood', 21: 'were', 22: 'more', 23: 'some', 24: 'two', 25: 'been', 26: 'its', 27: 'their', 28: 'other', 29: 'time', 30: 'first', 31: 'also', 32: 'life', 33: 'his', 34: 'years', 35: 'than', 36: 'about', 37: 'between', 38: 'he', 39: 'our', 40: 'only', 41: 'biblical', 42: 'when', 43: 'such', 44: 'may', 45: 'no', 46: 'nature', 47: 'most', 48: 'what', 49: 'will', 50: 'evidence', 51: 'fossil', 52: 'found', 53: 'who', 54: 'could', 55: 'i', 56: 'both', 57: 'into', 58: 'because', 59: 'animals', 60: 'different', 61: 'design', 62: 'so', 63: 'day', 64: 'record', 65: 'does', 66: 'carbon', 67: 'many', 68: 'same', 69: 'account', 70: 'universe', 71: 'however', 72: 'second', 73: 'very', 74: 'how', 75: 'should', 76: 'had', 77: 'us', 78: 'world', 79: 'rocks', 80: 'days', 81: 'even', 82: 'used', 83: 'p', 84: 'new', 85: 'do', 86: 'fossils', 87: 'man', 88: 'thus', 89: 'science', 90: 'any', 91: 'over', 92: 'data', 93: 'where', 94: 'each', 95: 'way', 96: 'much', 97: 'form', 98: 'before', 99: 'human', 100: 'then', 101: 'made', 102: 'three', 103: 'see', 104: 'bible', 105: 'hebrew', 106: 'organisms', 107: 'while', 108: 'literary', 109: 'water', 110: 'theory', 111: 'example', 112: 'scientific', 113: 'must', 114: 'created', 115: 'after', 116: 'system', 117: 'well', 118: 'out', 119: 'present', 120: 'long', 121: 'text', 122: 'since', 123: 'paleozoic', 124: 'like', 125: 'just', 126: 'through', 127: 'old', 128: 'narrative', 129: 'view', 130: 'history', 131: 'study', 132: 'humans', 133: 'you', 134: 'modern', 135: 'part', 136: 'living', 137: 'up', 138: 'land', 139: 'another', 140: 'similar', 141: 'during', 142: 'several', 143: 'model', 144: 'being', 145: 'case', 146: 'make', 147: 'point', 148: 'natural', 149: 'light', 150: 'book', 151: 'death', 152: 'major', 153: 'meaning', 154: 'information', 155: 'age', 156: 'ark', 157: 'story', 158: 'did', 159: 'possible', 160: 'now', 161: 'within', 162: 'here', 163: 'word', 164: 'upon', 165: 'given', 166: 'cambrian', 167: 'elements', 168: 'important', 169: 'above', 170: 'evolutionary', 171: 'large', 172: 'ancient', 173: 'gods', 174: 'find', 175: 'rather', 176: 'sources', 177: 'name', 178: 'number', 179: 'might', 180: 'evolution', 181: 'based', 182: 'fact', 183: 'origin', 184: 'work', 185: 'flesh', 186: 'sabbath', 187: 'formation', 188: 'known', 189: 'without', 190: '–', 191: 'appears', 192: 'question', 193: 'structure', 194: 'forms', 195: 'material', 196: 'order', 197: 'chapter', 198: 'great', 199: 'seems', 200: 'period', 201: 'deposits', 202: 'passages', 203: 'bc', 204: 'energy', 205: 'good', 206: 'lower', 207: 'appear', 208: 'care', 209: 'suggested', 210: 'species', 211: 'last', 212: 'use', 213: 'beginning', 214: 'why', 215: 'times', 216: 'dinosaurs', 217: 'section', 218: 'plate', 219: 'statement', 220: 'words', 221: 'source', 222: 'statements', 223: 'laws', 224: 'argument', 225: 'therefore', 226: 'layers', 227: 'every', 228: 'animal', 229: 'believe', 230: 'still', 231: 'formed', 232: 'explain', 233: 'cannot', 234: 'rock', 235: 'general', 236: 'intelligent', 237: 'seen', 238: 'rest', 239: 'solar', 240: 'result', 241: 'provide', 242: 'research', 243: 'geologic', 244: 'standard', 245: 'called', 246: 'hypothesis', 247: 'surface', 248: 'least', 249: 'planet', 250: 'earth’s', 251: 'testament', 252: 'described', 253: 'observed', 254: 'original', 255: 'my', 256: 'divine', 257: 'body', 258: 'chronological', 259: 'pattern', 260: 'process', 261: 'existence', 262: 'according', 263: 'scientists', 264: 'things', 265: 'few', 266: 'although', 267: 'explanation', 268: 'whole', 269: 'ages', 270: 'remains', 271: 'significant', 272: 'j', 273: 'problem', 274: 'chronology', 275: 'early', 276: 'thought', 277: 'suggest', 278: 'common', 279: 'passage', 280: 'literal', 281: 'matter', 282: 'certain', 283: 'term', 284: 'later', 28 ...

# %%
#TSV
out_v= io.open('vecs.tsv', 'w', encoding='utf-8')
out_m= io.open('meta.tsv', 'w', encoding='utf-8')

for word_num in range(1, vocab_size):
    word= rev_vocab[word_num]
    embeddings= weights[word_num]
    out_m.write(word + "\n")
    out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")

out_v.close()
out_m.close()

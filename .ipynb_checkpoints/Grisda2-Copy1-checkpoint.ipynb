# %%
from bs4 import BeautifulSoup
import re
import requests

# %%
from spacy.lang.en import English
import spacy
from spacy.matcher import Matcher
from spacy.matcher import PhraseMatcher
from spacy.tokens import Span
from spacy.language import Language
from spacy.training import Example

import numpy as np
import pandas as pd
import random

from nltk.probability import FreqDist
import random

# %%
#URLs
main_url= 'https://www.grisda.org'
url1= 'https://www.grisda.org/articles?primary=geology&secondary=geologic-processes'
url2= 'https://www.grisda.org/articles?page=2&secondary=geologic-processes'
url3= 'https://www.grisda.org/articles?page=3&secondary=geologic-processes'
url4= 'https://www.grisda.org/articles?page=4&secondary=geologic-processes'

#Get info from grid boxes
def getInfo(url):
    r= requests.get(url)
    soup= BeautifulSoup(r.text, 'html.parser')
    #Get grid with title and link
    grids= soup.section.find('div', {'id': 'article'}).div.div.find_all('div', class_='grid-line')
    
    #Get title, author, date and link
    info= []
    for grid in grids:
        info.append({
            'title_author': grid.h3.text,            
            'date': grid.time.text,
            'link': grid.a['href']
        })
    
    return info

#Get title and article 
def getArticle(page_n):
    r= requests.get(main_url+page_n['link'])
    soup= BeautifulSoup(r.text, 'html.parser')
    page= soup.find('div', class_='page')
    
    #Return None
    if page == None:
        return None
    
    #Remove figures
    for fig in page.select('figure'):
        fig.extract()
        
    #Get article body
    tex= ''
    for info in page.find_all('p'):
        tex+= info.text
    
    #Split by footer
    tex= re.split('ENDNOTES|Endnotes|REFERENCES|References|Footnotes|FOR FURTHER STUDY|LITERATURE CITED', tex)[0]
    
    #Remove first cite
    bib_pat= r'(.+doi.+(Summary\. ?|\n)|.+DOI.+(Summary\. ?|\n))'
    tex= re.sub(bib_pat,'', tex)
        
    #Remove cites
    cites_pat= r'\[[\w\.;,\- ]+\]'
    tex= re.sub(cites_pat,'', tex)
    
    #Remove parenthesis
    pars_pat= r'\([\w\.;,\- ]+\)'
    tex= re.sub(pars_pat,'', tex)
    
    #Remove Figure mentions
    figs_pat= r'[F|f]ig[\.\w]+ [\w,\- ]+|see [F|f]ig[\.\w]+ [\w,\- ]+'
    tex= re.sub(figs_pat,'', tex)
    
    #Remove stop words
    strwords= r'WHAT THIS ARTICLE IS ABOUT|ABSTRACT|INTRODUCTION|ACKNOWLEDGMENTS?|CONCLUSIONS?|Conclusions?|SUMMARY|DISCUSSION|Geoscience Research Institute'
    tex= re.sub(strwords,'', tex)
            
    #Get title and article body
    doc= {
        'title': page_n['title_author'],
        'doc': tex
         }
    
    return doc

def normalize(tex):
    #Lowercase
    tex= tex.lower()
    #Remove punctuation
    tex= re.sub(r'[^\w\s]','', tex)
    #Remove white spaces
    texf= tex.strip()
    #Tokenize
    #tokens= word_tokenize(tex)
    #textf= nltk.Text(tokens)
    
    return texf

# %%
#Get grid boxes
page1= getInfo(url1)
page2= getInfo(url2)
page3= getInfo(url3)
page4= getInfo(url4)

#Get articles
docs= []
for pagen in [page1, page2, page3, page4]:
    for page in pagen:
        docs.append(getArticle(page))

#Remove None
docs= list(filter(None, docs))
#Remove biblio
docs[8]['doc']= re.split('Ariel A. Roth', docs[8]['doc'])[0]
#Remove film review
del docs[4]

# %%
#Tokenize articles
tokens= []
tokens_normalized= []

nlp= English()

for doc in docs:
    tokens.append(nlp(doc['doc']))
    tokens_normalized.append(nlp(normalize(doc['doc'])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-6687302472df> in <module>
#       3 tokens_normalized= []
#       4
# ----> 5 nlp= English()
#       6
#       7 for doc in docs:
#
# NameError: name 'English' is not defined

# %%
"""
1.1 Entities
ORG: Paleozoic 54, Genesis 36, Cenozoic 17, the National Academy of Sciences 16
PERSON: Carey 27, Bretz 12, Noah 9, Darwin 9
"""

nlp= spacy.load('en_core_web_sm')

#Entities per article
all_entities= []
for doc in docs:
    #print(doc['title'])
    entit= nlp(doc['doc'])
    
    entities= []
    for tok in entit.ents:        
        #print(tok.text, tok.label_)
        entities.append((tok.text, tok.label_))
    
    all_entities.append(entities)
    entities= []

#Flat list
all_entities= [item for sublist in all_entities for item in sublist]

#PERSON GPE ORG LOC
specific= []
for enti in all_entities:
    if(enti[1]== 'PERSON'):
        specific.append(enti)

FreqDist(specific).most_common(10)
# Out:
# [(('Carey', 'PERSON'), 27),
#  (('Bretz', 'PERSON'), 12),
#  (('Archaeopteryx', 'PERSON'), 11),
#  (('Noah', 'PERSON'), 9),
#  (('Darwin', 'PERSON'), 9),
#  (('Vine', 'PERSON'), 7),
#  (('Alvarez', 'PERSON'), 6),
#  (('Dinosaurs', 'PERSON'), 6),
#  (('Pliocene', 'PERSON'), 6),
#  (('Davidson', 'PERSON'), 6)]

# %%
"""
1.2 Entities
GPE: Australia 30, Iceland 28, Utah 23, Greenland 20, Canada 17, Arizona 16, California 15
LOC: Earth 121, Flood 47, Europe 38, North America 28, the Grand Canyon 26, Asia 20, Antarctica 17
"""

nlp= spacy.load('en_core_web_sm')
####Probar con large (Otros modelos)#####

#Entities per article
all_entities= []
for doc in docs:
    #print(doc['title'])
    entit= nlp(doc['doc'])
    
    entities= []
    for tok in entit.ents:        
        #print(tok.text, tok.label_)
        entities.append((tok.text, tok.label_))
    
    all_entities.append(entities)
    entities= []

#Flat list
all_entities= [item for sublist in all_entities for item in sublist]

#PERSON GPE ORG LOC
specific= []
for enti in all_entities:
    if(enti[1]== 'LOC'):
        specific.append(enti)

FreqDist(specific).most_common(10)
# Out:
# [(('Earth', 'LOC'), 121),
#  (('Flood', 'LOC'), 47),
#  (('Europe', 'LOC'), 38),
#  (('North America', 'LOC'), 28),
#  (('the Grand Canyon', 'LOC'), 26),
#  (('Asia', 'LOC'), 20),
#  (('Antarctica', 'LOC'), 17),
#  (('Mars', 'LOC'), 15),
#  (('Mount St. Helens', 'LOC'), 15),
#  (('Pacific', 'LOC'), 14)]

# %%
"""
1.3 Matcher
Origin of: life 13
"""

nlp= spacy.load('en_core_web_sm')
matcher= Matcher(nlp.vocab)
pattern= [{"TEXT": "origin"}, {"TEXT": "of"}, {"POS": "NOUN"}]

matcher.add("ORIGIN", [pattern])

all_origins= []
for doc in docs:
    mat= nlp(doc['doc'])
    matches= matcher(mat)
    
    if matches:
        print(doc['title'])
        for match_id, start, end in matches:
            all_origins.append(mat[start:end].text)
            
        print([mat[start:end].text for match_id, start, end in matches])
        print()

FreqDist(all_origins).most_common(10)
# Out:
# The Precambrian: Part 3 of 3–by Benjamin L. Clausen
# ['origin of life']
#
# Glaciations and the Geologic Record–by Ronny Nalin
# ['origin of deposits']
#
# Catastrophism: Discussion of Its Current Status in Geology, and a Prediction–by Leonard R. Brand
# ['origin of life']
#
# Annotations from the Literature
# ['origin of shelf']
#
# Annotations from the Literature
# ['origin of life']
#
# Annotations from the Literature
# ['origin of life']
#
# Annotations from the Literature–by L. James Gibson
# ['origin of life', 'origin of life', 'origin of eukaryotes']
#
# Geological Society of America Meeting–by Kurt P. Wise, Arthur V. Chadwick
# ['origin of echinoderm', 'origin of complexity']
#
# False Fossils–by Ariel A. Roth
# ['origin of life']
#
# Annotations from the Literature
# ['origin of life', 'origin of life', 'origin of turtles']
#
# Annotations from the Literature
# ['origin of life', 'origin of life', 'origin of life', 'origin of eukaryotes']
#
# Expanding Earth?–by Bill Mundy
# ['origin of volcanism']
#
# Those Gaps in the Sedimentary Layers–by Ariel A. Roth
# ['origin of paraconformities']
#
# Some Questions about Geochronology–by Ariel A. Roth
# ['origin of limestone']
#
# Annotations from the Literature
# ['origin of life']
#
# Are Millions of Years Required to Produce Biogenic Sediments in the Deep Ocean?–by Ariel A. Roth
# ['origin of sediments']
#
# Anomalous Ages for Meteorite Impacts and Tektites–by Warren H. Johns
# ['origin of tektites']
# [('origin of life', 13),
#  ('origin of eukaryotes', 2),
#  ('origin of deposits', 1),
#  ('origin of shelf', 1),
#  ('origin of echinoderm', 1),
#  ('origin of complexity', 1),
#  ('origin of turtles', 1),
#  ('origin of volcanism', 1),
#  ('origin of paraconformities', 1),
#  ('origin of limestone', 1)]

# %%
"""
1.4 Lexical attributes
Versicles: Genesis 7:11 - 5
           Genesis 7    - 8
           Genesis 1    - 7
"""

nlp= spacy.load('en_core_web_sm')

all_versicles= []
for doc in docs:
    artic= nlp(doc['doc'])
    
    for tok in artic:
        if(tok.text == 'Genesis'):
            if(artic[tok.i+1].pos_ == 'NUM'):
                print(doc['title'])
                all_versicles.append(tok.text+' '+artic[tok.i+1].text)
                print(tok.text, artic[tok.i+1].text)
                print()

FreqDist(all_versicles).most_common(10)
# Out:
# Dinosaurs and Dust–by Jim Gibson
# Genesis 7
#
# What Is the Evidence for a Large Asteroid Impact at the Cretaceous-Paleogene (K-Pg) Boundary?–by Ronny Nalin
# Genesis 7:11
#
# The Paleozoic Rock Record: A Broad Overview of Features and Trends–by Ronny Nalin
# Genesis 6
#
# The Precambrian: Part 3 of 3–by Benjamin L. Clausen
# Genesis 1
#
# The Role of Catastrophes in Scientific Thinking–by Ariel A. Roth
# Genesis 6:6
#
# Climbing Up and Down Through the Fossil Record–by Ariel A. Roth
# Genesis 1
#
# The Enigmatic Geologic Column–by L. James Gibson
# Genesis 11:18
#
# A Note on the Pre-Flood/Flood Boundary in the Grand Canyon–by Kurt P. Wise, Andrew Snelling
# Genesis 7:11
#
# A Note on the Pre-Flood/Flood Boundary in the Grand Canyon–by Kurt P. Wise, Andrew Snelling
# Genesis 7:11
#
# Unique Enigmatic Helium–by Robert H. Brown
# Genesis 1:10
#
# The Canyon of Canyons–by Robert H. Brown
# Genesis 1:6
#
# The Canyon of Canyons–by Robert H. Brown
# Genesis 7:11
#
# The Implications of the Oklo Phenomenon on the Constancy of Radiometric Decay Rates–by Clyde L. Webster Jr.
# Genesis 1:1
#
# The Implications of the Oklo Phenomenon on the Constancy of Radiometric Decay Rates–by Clyde L. Webster Jr.
# Genesis 1
#
# A Post-Flood Ice-Age Model Can Account for Quaternary Features–by Michael J. Oard
# Genesis 7:11
#
# A Post-Flood Ice-Age Model Can Account for Quaternary Features–by Michael J. Oard
# Genesis 7:19
#
# Reversal of Earth's Magnetic Field–by Robert H. Brown
# Genesis 7
#
# NASA's Next Interplanetary Mission–by David H. Rhys
# Genesis 1:2
# [('Genesis 7:11', 5),
#  ('Genesis 1', 3),
#  ('Genesis 7', 2),
#  ('Genesis 6', 1),
#  ('Genesis 6:6', 1),
#  ('Genesis 11:18', 1),
#  ('Genesis 1:10', 1),
#  ('Genesis 1:6', 1),
#  ('Genesis 1:1', 1),
#  ('Genesis 7:19', 1)]

# %%
"""
2.0.5 ADJ flood
___ flood: biblical 19, global 16, worldwide 16
"""

nlp= spacy.load("en_core_web_md")

all_nouns= []
for doc in docs:
    artic= nlp(doc['doc'])
    
    art_nouns= []
    for tok in artic:
        if(tok.text == 'flood'):
            if(artic[tok.i-1].pos_ == 'ADJ' and len(artic[tok.i-1].text) > 2):
                art_nouns.append(artic[tok.i-1].text+' '+tok.text)
    
    
    if art_nouns:
        all_nouns.append(art_nouns)
        print(doc['title'])
        print(art_nouns)
        print()

#Flat list
all_nouns= [item for sublist in all_nouns for item in sublist]
#Lowercase
all_nouns= [x.lower() for x in all_nouns]

FreqDist(all_nouns).most_common(10)
# Out:
# The Grand Staircase: a Case Study in Scientific Thinking from a Biblical Worldview–by Leonard R. Brand
# ['wide flood', 'wider flood']
#
# What Is the Evidence for a Large Asteroid Impact at the Cretaceous-Paleogene (K-Pg) Boundary?–by Ronny Nalin
# ['cataclysmic flood', 'global flood']
#
# The Geological Story Told by Iceland
# ['small flood', 'sedimentary flood', 'global flood']
#
# The Paleozoic Rock Record: A Broad Overview of Features and Trends–by Ronny Nalin
# ['global flood']
#
# The Role of Catastrophes in Scientific Thinking–by Ariel A. Roth
# ['catastrophic flood', 'unwanted flood', 'several flood', 'recent flood']
#
# Catastrophic Earth Science: A Realistic Science–by Roberto E. Biaggi
# ['planetary flood']
#
# The Enigmatic Geologic Column–by L. James Gibson
# ['Biblical flood', 'Biblical flood', 'global flood', 'local flood', 'global flood']
#
# Wholistic Geology: Geology Before, During, and After the Biblical Flood–by Leonard R. Brand
# ['Traditional flood', 'biblical flood', 'global flood', 'global flood', 'traditional flood', 'global flood', 'literal flood', 'catastrophic flood', 'global flood', 'Biblical flood', 'biblical flood', 'alternative flood', 'global flood', 'global flood', 'traditional flood', 'traditional flood', 'traditional flood', 'traditional flood', 'traditional flood', 'traditional flood', 'global flood', 'global flood']
#
# Annotations from the Literature
# ['large flood', 'global flood', 'global flood']
#
# Annotations from the Literature
# ['Siberian flood', 'Siberian flood', 'Siberian flood', 'Siberian flood']
#
# Annotations from the Literature–by L. James Gibson
# ['Biblical flood', 'catastrophic flood', 'single flood']
#
# Local Catastrophes, or a Worldwide Deluge?–by L. James Gibson
# ['biblical flood', 'tranquil flood', 'local flood', 'local flood', 'biblical flood', 'biblical flood', 'Mesopotamian flood', 'biblical flood', 'alternative flood', 'biblical flood', 'biblical flood', 'biblical flood', 'impending flood', 'local flood', 'biblical flood']
#
# The Yellowstone Fossil “Forests"–by Harold G. Coffin
# ['worldwide flood']
#
# Incomplete Ecosystems–by Ariel A. Roth
# ['biblical flood']
#
# A Post-Flood Ice-Age Model Can Account for Quaternary Features–by Michael J. Oard
# ['extensive flood']
#
# A Catastrophe With an Impact–by L. James Gibson
# ['continental flood', 'biblical flood', 'biblical flood', 'biblical flood', 'worldwide flood']
#
# Those Gaps in the Sedimentary Layers–by Ariel A. Roth
# ['catastrophic flood', 'catastrophic flood', 'catastrophic flood']
#
# Examining Radiohalos (Review of Creation’s Tiny Mystery)–by Ariel A. Roth, L. James Gibson, Harold G. Coffin, Robert H. Brown, Clyde L. Webster Jr.
# ['Noachian flood', 'Noachian flood']
#
# Some Questions about Geochronology–by Ariel A. Roth
# ['worldwide flood', 'worldwide flood']
#
# The Mexico Earthquake–by Ariel A. Roth
# ['worldwide flood']
#
# Can Science and Religion Work Together?–by Leonard R. Brand
# ['worldwide flood', 'worldwide flood', 'worldwide flood', 'worldwide flood', 'worldwide flood', 'Noachian flood', 'biblical flood', 'worldwide flood']
#
# Are Millions of Years Required to Produce Biogenic Sediments in the Deep Ocean?–by Ariel A. Roth
# ['worldwide flood', 'worldwide flood', 'worldwide flood', 'worldwide flood']
#
# Mount St. Helens and Spirit Lake–by Harold G. Coffin
# ['global flood', 'worldwide flood']
#
# Anomalous Ages for Meteorite Impacts and Tektites–by Warren H. Johns
# ['Noachian flood']
# [('biblical flood', 19),
#  ('global flood', 16),
#  ('worldwide flood', 16),
#  ('traditional flood', 8),
#  ('catastrophic flood', 6),
#  ('local flood', 4),
#  ('siberian flood', 4),
#  ('noachian flood', 4),
#  ('alternative flood', 2),
#  ('wide flood', 1)]

# %%
"""
2.1 Similarity Flood ADJs
Higher: global-worldwide: .68, local-traditional: .44, global-cathastrophic: .41
"""

flood_adjs= FreqDist(all_nouns).most_common(6)
only_adjs= [x[0].split()[0] for x in flood_adjs]
print(only_adjs)
print()

all_sims= []
for adx in only_adjs:
    doc1= nlp(adx)
    sim= []
    
    for ady in only_adjs:
        doc2= nlp(ady)
        sim.append(doc1.similarity(doc2))
        
    all_sims.append(sim)

arr= np.array(all_sims)
abr= [x[0:4] for x in only_adjs]
df= pd.DataFrame(data=arr, index=abr, columns=abr)
print(df)
# Out:
# ['biblical', 'global', 'worldwide', 'traditional', 'catastrophic', 'local']
#
#           bibl      glob      worl      trad      cata      loca
# bibl  1.000000  0.219193  0.183293  0.337872  0.229385  0.127923
# glob  0.219193  1.000000  0.685584  0.282038  0.419587  0.355571
# worl  0.183293  0.685584  1.000000  0.268425  0.273535  0.288525
# trad  0.337872  0.282038  0.268425  1.000000  0.135243  0.447429
# cata  0.229385  0.419587  0.273535  0.135243  1.000000  0.157987
# loca  0.127923  0.355571  0.288525  0.447429  0.157987  1.000000

# %%
"""
2.2 Similarity Flood ADJs
Higher: global-worldwide: .87, global-cathastrophic: .79
"""

flood_adjs= FreqDist(all_nouns).most_common(6)
only_adjs= [x[0] for x in flood_adjs]
print(only_adjs)
print()

all_sims= []
for adx in only_adjs:
    doc1= nlp(adx)
    sim= []
    
    for ady in only_adjs:
        doc2= nlp(ady)
        sim.append(doc1.similarity(doc2))
        
    all_sims.append(sim)

arr= np.array(all_sims)
abr= [x[0:4] for x in only_adjs]
df= pd.DataFrame(data=arr, index=abr, columns=abr)
print(df)
# Out:
# ['biblical flood', 'global flood', 'worldwide flood', 'traditional flood', 'catastrophic flood', 'local flood']
#
#           bibl      glob      worl      trad      cata      loca
# bibl  1.000000  0.679614  0.670270  0.722369  0.711905  0.659430
# glob  0.679614  1.000000  0.878600  0.709283  0.793084  0.758465
# worl  0.670270  0.878600  1.000000  0.704914  0.750450  0.737629
# trad  0.722369  0.709283  0.704914  1.000000  0.687908  0.785520
# cata  0.711905  0.793084  0.750450  0.687908  1.000000  0.720199
# loca  0.659430  0.758465  0.737629  0.785520  0.720199  1.000000

# %%
"""
2.3 Phrase Matcher - Root
VERB: Earth expanding 25
"""

nlp= spacy.load("en_core_web_md")

matcher= Matcher(nlp.vocab)
pattern= [{"POS": "VERB"}]
matcher.add("PLACE", [pattern])

alls= []
for doc1 in docs:
    doc= nlp(doc1['doc'])
    doc.ents= []
    
    for match_id, start, end in matcher(doc):
        span= Span(doc, start, end, label="VERB")

        doc.ents = list(doc.ents) + [span]
        span_root_head= span.root.head
        if(span_root_head.text != span.text and len(span.text) > 4 and len(span_root_head) > 4):
            alls.append(span_root_head.text+" --> "+span.text)
            #print(span_root_head.text, "-->", span.text)

FreqDist(alls).most_common(15)
# Out:
# [('earth --> expanding', 25),
#  ('flood --> described', 11),
#  ('difficult --> explain', 9),
#  ('organisms --> living', 8),
#  ('proposed --> explain', 7),
#  ('amount --> involved', 6),
#  ('fossils --> preserved', 6),
#  ('field --> produced', 6),
#  ('trend --> cooling', 6),
#  ('charges --> moving', 6),
#  ('plants --> flowering', 5),
#  ('erosion --> expected', 5),
#  ('theory --> proposed', 5),
#  ('changes --> occurred', 5),
#  ('surfaces --> growing', 5)]

# %%
"""
2.4 Phrase Matcher - Root
ADJ: Geologic column 33, organic levels 32
"""

nlp= spacy.load("en_core_web_md")

matcher= Matcher(nlp.vocab)
pattern= [{"POS": "ADJ"}]
matcher.add("PLACE", [pattern])

alls= []
for doc1 in docs[:30]:
    doc= nlp(doc1['doc'])
    doc.ents= []
    
    for match_id, start, end in matcher(doc):
        span= Span(doc, start, end, label="ADJ")

        doc.ents = list(doc.ents) + [span]
        span_root_head= span.root.head
        if(span_root_head.text != span.text and len(span.text) > 4 and len(span_root_head) > 4):
            alls.append(span.text+" --> "+span_root_head.text)
            #print(span_root_head.text, "-->", span.text)

FreqDist(alls).most_common(15)
# Out:
# [('geologic --> column', 33),
#  ('organic --> levels', 32),
#  ('petrified --> trees', 20),
#  ('wholistic --> geology', 19),
#  ('geological --> processes', 17),
#  ('geologic --> record', 17),
#  ('organic --> matter', 16),
#  ('outer --> space', 16),
#  ('large --> scale', 15),
#  ('global --> flood', 14),
#  ('petrified --> forests', 11),
#  ('biblical --> flood', 10),
#  ('common --> ancestor', 10),
#  ('secondary --> process', 9),
#  ('upright --> trees', 9)]

# %%
"""
3.1 Pipe: ELEMENTS
Found: mobile ELEMENTS
"""

nlp= spacy.load("en_core_web_sm")

elems= ['mafic', 'felsic', 'intermediate', 'mobile', 'inmobile', 'alkaline']
elem_patterns= list(nlp.pipe(elems))
print("elements_patterns:", elem_patterns)

name= 'ELEMENTS'
matcher= PhraseMatcher(nlp.vocab)
matcher.add(name, elem_patterns)

@Language.component('el_component')
def el_component(doc):
    matches= matcher(doc)
    spans= [Span(doc, start, end, label=name) for match_id, start, end in matches]
    doc.ents= spans
    
    return doc

nlp.add_pipe('el_component', after="ner")
print()

li= []
for doc in docs:
    doco= nlp(doc['doc'])
    li.append([(ent.text, ent.label_) for ent in doco.ents])

#Flat list
li= [item for sublist in li for item in sublist]
print(li)
# Out:
# elements_patterns: [mafic, felsic, intermediate, mobile, inmobile, alkaline]
#
# [('mafic', 'ELEMENTS'), ('alkaline', 'ELEMENTS'), ('intermediate', 'ELEMENTS'), ('mobile', 'ELEMENTS'), ('intermediate', 'ELEMENTS'), ('mobile', 'ELEMENTS'), ('mobile', 'ELEMENTS'), ('mobile', 'ELEMENTS'), ('mobile', 'ELEMENTS'), ('mobile', 'ELEMENTS'), ('mobile', 'ELEMENTS'), ('mobile', 'ELEMENTS'), ('mobile', 'ELEMENTS'), ('alkaline', 'ELEMENTS')]

# %%
"""
3.2 Pipe: DISASTER
eruption 55, earthquake 50, volcanism 41, tsunami 12, hurricane 5
"""

nlp= spacy.load("en_core_web_sm")

elems= ['earthquake', 'earthquakes', 'volcanism', 'hurricane', 'hurricanes', 'tsunami', 'tsunamis', 'eruption']
elem_patterns= list(nlp.pipe(elems))
print("elements_patterns:", elem_patterns)

name= 'DISASTERS'
matcher= PhraseMatcher(nlp.vocab)
matcher.add(name, elem_patterns)

@Language.component('el_component')
def el_component(doc):
    matches= matcher(doc)
    spans= [Span(doc, start, end, label=name) for match_id, start, end in matches]
    doc.ents= spans
    
    return doc

nlp.add_pipe('el_component', after="ner")
#print(nlp.pipe_names)
print()

li= []
for doc in docs:
    doco= nlp(doc['doc'])
    li.append([(ent.text, ent.label_) for ent in doco.ents])

#Flat list
li= [item for sublist in li for item in sublist]
li= [x[0] for x in li]

li2= []
for i in li:
    if (i[-1]=='s'):
        li2.append(i[:-1])
    else:
        li2.append(i)

FreqDist(li2).most_common()
# Out:
# elements_patterns: [earthquake, earthquakes, volcanism, hurricane, hurricanes, tsunami, tsunamis, eruption]
# [('eruption', 55),
#  ('earthquake', 50),
#  ('volcanism', 41),
#  ('tsunami', 12),
#  ('hurricane', 5)]

# %%
"""
3.4 

"""
nlp= spacy.load("en_core_web_sm") 
#nlp= spacy.blank('en')

# Getting the ner component
ner= nlp.get_pipe('ner')

LABEL= "DISASTER"

TRAIN_DATA =[ ("An earthquake is what happens when two blocks of the earth suddenly slip past one another.", {"entities":[(3, 13, "DISASTER")]}),
              ("Earthquakes are recorded by instruments called seismographs.", {"entities":[(0, 11, "DISASTER")]}),
              ("The size of an earthquake depends on the size of the fault and the amount of slip on the fault", {"entities":[(15,25, "DISASTER")]}),
              ("A short wiggly line that doesn’t wiggle very much means a small earthquake", {"entities":[(64,74, "DISASTER")]}),
              ("The size of the earthquake is called its magnitude.", {"entities":[(16,26, "DISASTER")]}),
              ("Tsunamis are giant waves caused by earthquakes or volcanic eruptions under the sea.", {"entities":[(0,8, "DISASTER"),(35,46, "DISASTER"),(50,68, "DISASTER")]}),
              ("Explosive eruptions are characterized by gas-driven explosions", {"entities":[(0,19, "DISASTER")]}),
              ("Flows from Hawaiian eruptions are basaltic", {"entities":[(11,29, "DISASTER")]}),
              ("Tsunami waves may travel as fast as jet planes over deep waters", {"entities":[(0,7, "DISASTER")]}),
              ("While tsunamis are often referred to as tidal waves", {"entities":[(6,14, "DISASTER")]}),
              ("The understanding of tsunamis remained slim until the 20th century", {"entities":[(21,29, "DISASTER")]}),
              ("However, like tsunami, seismic sea wave is not a completely accurate term", {"entities":[(14,21, "DISASTER")]}),
              ("Examples of tsunamis originating at locations away", {"entities":[(12,20, "DISASTER")]}),
              ("Volcanic eruptions happen when lava and gas are discharged from a volcanic vent.", {"entities":[(0,18, "DISASTER")]}),
              ("Volcanic eruptions, underwater explosions, land or ice slumping into the ocean", {"entities":[(0,18, "DISASTER"),(20,41, "DISASTER")]}),
              ("The Grand Canyon was carved through Precambrian and Paleozoic rocks", {"entities":[(4,16, "LOC")]}),
              ("The Grand Staircase actually is a series of cliffs.", {"entities":[(4,19, "DISASTER")]}),
              ("Examples of tsunamis originating at locations away", {"entities":[(12,20, "DISASTER")]}),
              ("Examples of tsunamis originating at locations away", {"entities":[(12,20, "DISASTER")]}),
              ("Examples of tsunamis originating at locations away", {"entities":[(12,20, "DISASTER")]}),
              ("Examples of tsunamis originating at locations away", {"entities":[(12,20, "DISASTER")]}),
              ("Examples of tsunamis originating at locations away", {"entities":[(12,20, "DISASTER")]})
           ]

# Add the new label to ner
ner.add_label(LABEL)

# Resume training
optimizer = nlp.resume_training()
move_names = list(ner.move_names)

# List of pipes you want to train
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]

# List of pipes which should remain unaffected in training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# Begin training by disabling other pipeline components
with nlp.disable_pipes(*other_pipes) :
    # Training for 30 iterations
    for i in range(50):
    # Shuffle the training data
        random.shuffle(TRAIN_DATA)

        for raw_data, entity_offsets in TRAIN_DATA:
            doc = nlp.make_doc(raw_data)
            example = Example.from_dict(doc, {"entities": entity_offsets['entities']})
            nlp.update([example], sgd=optimizer)


test_text = "I survived 3 tsunamis and earthquakes with Godzilla."
doc = nlp(test_text)

print("Entities in '%s'" % test_text)
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Entities in 'I survived 3 tsunamis and earthquakes with Godzilla.'
# tsunamis DISASTER
# Godzilla. DISASTER

# %%
"""
4.0.5 Training data for DISASTER
"""

nlp=spacy.load('en_core_web_sm')

# Getting the pipeline component
ner=nlp.get_pipe("ner")

#GPE: Australia 30, Iceland 28, Utah 23, Greenland 20, Canada 17, Arizona 16, California 15
TRAIN_DATA =[ ("An earthquake is what happens when two blocks of the earth suddenly slip past one another.", {"entities":[(3, 13, "DISASTER")]}),
              ("Earthquakes are recorded by instruments called seismographs.", {"entities":[(0, 11, "DISASTER")]}),
              ("The size of an earthquake depends on the size of the fault and the amount of slip on the fault", {"entities":[(15,25, "DISASTER")]}),
              ("A short wiggly line that doesn’t wiggle very much means a small earthquake", {"entities":[(64,74, "DISASTER")]}),
              ("The size of the earthquake is called its magnitude.", {"entities":[(16,26, "DISASTER")]}),
              ("Tsunamis are giant waves caused by earthquakes or volcanic eruptions under the sea.", {"entities":[(0,8, "DISASTER"),(35,46, "DISASTER"),(50,68, "DISASTER")]}),
              ("Explosive eruptions are characterized by gas-driven explosions", {"entities":[(0,19, "DISASTER")]}),
              ("Flows from Hawaiian eruptions are basaltic", {"entities":[(11,29, "DISASTER")]}),
              ("Tsunami waves may travel as fast as jet planes over deep waters", {"entities":[(0,7, "DISASTER")]}),
              ("While tsunamis are often referred to as tidal waves", {"entities":[(6,14, "DISASTER")]}),
              ("The understanding of tsunamis remained slim until the 20th century", {"entities":[(21,29, "DISASTER")]}),
              ("However, like tsunami, seismic sea wave is not a completely accurate term", {"entities":[(14,21, "DISASTER")]}),
              ("Examples of tsunamis originating at locations away", {"entities":[(12,20, "DISASTER")]}),
              ("Volcanic eruptions happen when lava and gas are discharged from a volcanic vent.", {"entities":[(0,18, "DISASTER")]}),
              ("Volcanic eruptions, underwater explosions, land or ice slumping into the ocean", {"entities":[(0,18, "DISASTER"),(20,41, "DISASTER")]}),
              ("The Grand Canyon was carved through Precambrian and Paleozoic rocks", {"entities":[(4,16, "LOC")]}),
              ("The Grand Staircase actually is a series of cliffs.", {"entities":[(4,19, "LOC")]}),
              ("Arizona is the 48th state and last of the contiguous states to be admitted to the Union.", {"entities":[(0,7, "GPE")]}),
              ("Arizona is home to a diverse population.", {"entities":[(0,7, "GPE")]}),
              ("Utah is known for its natural diversity and is home to features ranging from arid deserts with sand dunes to thriving pine forests in mountain valleys.", {"entities":[(0,4, "GPE")]}),
              ("The northernmost portion of the Mojave Desert is also located in this area.", {"entities":[(32,45, "LOC")]}),
              ("Utah features a dry, semi-arid to desert climate.", {"entities":[(0,4, "GPE")]}),
              ("When Mexico achieved its independence from the Kingdom of Spain", {"entities":[(5,11, "GPE"),(47,63, "ORG")]}),
              ("Generally, Arizona is at low risk of earthquakes.", {"entities":[(11,18, "GPE"),(37,48, "DISASTER")]}),
              ("Australia is the oldest, flattest, and driest inhabited continent, with the least fertile soils.", {"entities":[(0,9, "GPE")]}),
              ("We are anticipating additional requirements, and we got a signal from you", {"entities":[]}),
              ("Most of the lowland areas receive less than 12 inches (305 mm) of precipitation annually.", {"entities":[]}),
              ("Additionally, the pipeline package versioning reflects both the compatibility with spaCy", {"entities":[]}),
              ("Two years after Charles Darwin published his book", {"entities":[(16,30, "PERSON")]}),
              ("Noah and his family and representatives of the terrestrial vertebrates survived in an ark.", {"entities":[(0,4, "PERSON")]}),
              ("Perhaps during the hundreds of years before Noah", {"entities":[(44,48, "PERSON")]}),
              ("The Chicxulub asteroid impact would generate large amounts of SO2 and CO2.", {"entities":[(4,13, "GPE")]}),
              ("For those who are not geologists we will review several geological processes pertinent to study.", {"entities":[]}),
              ("How does that type of erosion happen?", {"entities":[]}),
              ("Causing overflow at the weir of the emergency spillway for the first time in the history of the dam", {"entities":[]}),
              ("Most importantly, the observation of bedrock erosion and formation of depositional bars over short time scales in a relatively localized area", {"entities":[]}),
              ("The lake level is controlled through a main spillway, consisting of a concrete chute nearly 1 km long and about 50 m.", {"entities":[]}),
              ("An emergency spillway, designed to be active in cases of extremely high lake levels, is located to the side (NW) of the main spillway", {"entities":[]}),
              ("View of channelized flow pattern diverting from damaged main spillway and confined to newly incised canyon.", {"entities":[]}),
              ("Only someone with personal confidence that the God of the Bible knows more about geology.", {"entities":[]}),
              ("– an opportunity for productive research that would probably not occur if our biblical worldview did not lead us to think it", {"entities":[]}),
              ("Some orders of magnitude lower than a megaflood with rates of ≥ 106 m3/s.", {"entities":[]}),
              ("Segregation of species in different seafloor habitats appears to be a feature of both modern and fossil communities.", {"entities":[]}),
              ("The bird Archaeopteryx and the amphibian Tiktaalik are two examples of mosaic fossils.", {"entities":[]}),
              ("Decision makers managing the crisis had to significantly increase the outflow rate at the main spillway (to 2800 m3/s)", {"entities":[]}),
              ("The canyon is just a giant gash across an uplifted part of the landscape.", {"entities":[]}),
              ("A creationist perspective interprets Peregocetus as an extinct animal.", {"entities":[]}),
              ("Carey reports the discovery of hominin remains from a different location.", {"entities":[(0,5, "PERSON")]}),
              ("In fact, Kellner described 33 features shared by all pterosaurs that no other animal possessed.", {"entities":[(9,16, "PERSON")]}),
              ("Dalla Vecchia concluded that Caviramus is actually Raeticodactylus.", {"entities":[(0,13, "PERSON")]}),
              ("Conway Morris maintains that microevolutionary processes are sufficient to explain invertebrate evolution.", {"entities":[(0,13, "PERSON")]}),
              ("Simonetta and Delle Cave begin their discussion with the statement.", {"entities":[(0,9, "PERSON"),(14,24, "PERSON")]}),
              ("An NER System is capable of discovering entity elements from raw data and determines the category the element belongs to.", {"entities":[]}),
              ("For a general entity such as name, location, organization, date and pre-trained library, Stanford NER and Spacy can be used.", {"entities":[]})
           ]

#Adding labels to the `ner`
for _, annotations in TRAIN_DATA:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])
        
#Disable pipeline components you dont need to change
pipe_exceptions= ["ner", "trf_wordpiecer", "trf_tok2vec"]
unaffected_pipes= [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
optimizer= nlp.resume_training()

with nlp.disable_pipes(*unaffected_pipes):
    #15 iterations
    for i in range(15):
        random.shuffle(TRAIN_DATA)

        for raw_data, entity_offsets in TRAIN_DATA:
            doc= nlp.make_doc(raw_data)
            example= Example.from_dict(doc, {"entities": entity_offsets['entities']})
            nlp.update([example], sgd=optimizer)

doc = nlp("I was driving in the Grand Staircase with Darwin and Noah trying to avoid a tsunami.")
print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Entities [('Grand Staircase', 'LOC'), ('Darwin', 'PERSON'), ('Noah', 'PERSON'), ('tsunami', 'DISASTER')]

# %%
"""
4.1 DISASTER
Train     Flood 45, earthquake 44, tsunami 12, volcanic eruption 6
Pipe      eruption 55, earthquake 50, volcanism 41, tsunami 12, hurricane 5
"""

ents= []
for doc in docs:
    doco= nlp(doc['doc'])
    
    for ent in doco.ents:
        ents.append((ent.text, ent.label_))

#DISASTER
specific= []
specs= []

for enti in ents:
    if(enti[1] == 'DISASTER'):
        if(enti[0][-1] == 's'):
            specs.append(enti[0][:-1])
        else:
            specs.append(enti[0])

elems= ['earthquake', 'hurricane', 'tsunami', 'volcanic eruption', 'Flood']
#elems= ['Earth', 'Bible', 'Tunguska', 'Helen', 'Europe', 'turtle', 'Antarctica', 'Asia']
for enti in specs:
    #if(enti not in elems):
    if(enti in elems):
        specific.append(enti)

FreqDist(specific).most_common(30)
# Out:
# [('Flood', 45), ('earthquake', 44), ('tsunami', 12), ('volcanic eruption', 6)]

# %%
"""
4.2 DISASTER ADJs
Found: Lisbon earthquake, Alaska earthquake, Chilean earthquake
"""

elems= ['earthquake', 'earthquakes', 'tsunami', 'tsunamis', 'volcanic eruption']

for doc in docs:
    doco= nlp(doc['doc'])
    
    for ent in doco:
        if (ent.ent_type_ == 'DISASTER'):
            if (ent.text in elems):
                if(len(doco[ent.i-1].text) > 5):
                    print(doco[ent.i-1].text, ent.text)
# Out:
# accompanying earthquakes
# larger earthquakes
# Lisbon earthquake
# frequent earthquakes
# Lisbon earthquake
# REJECTEDAn earthquake
# explains earthquakes
# describes earthquakes
# resulting tsunami
# Chilean earthquake
# magnitude earthquake
# midcontinental earthquakes
# Alaska earthquake
# Global earthquakes
# magnitude earthquake
# magnitude earthquake

# %%
"""
4.3 DISASTER - VERB
Found: earthquake shook, tsunami triggered
"""

alls= []
ents2= []
for doc1 in docs:
    
    doc= nlp(doc1['doc'])
    
    matcher= Matcher(nlp.vocab)
    patterns= [{"ENT_TYPE": "DISASTER"}]
    matcher.add("DIS2", [patterns])
    matches= matcher(doc)
    
    for match_id, start, end in matches:
        span= Span(doc, start, end, label="DIS2")
        ents2.append(span.text)
        span_root_head= span.root.head
        #print('Root', span_root_head.pos_)
        if (span.text in elems):
            if(span_root_head.text != span.text and len(span.text) > 4 and len(span_root_head) > 4):
                if(span_root_head.pos_ == 'VERB'):
                    alls.append(span.text+" --> "+span_root_head.text)
                    print(span_root_head.text, "-->", span.text)

FreqDist(alls).most_common(15)
# Out:
# related --> tsunami
# related --> tsunami
# REJECTEDAn --> earthquake
# loosened --> earthquake
# caused --> earthquake
# mentions --> earthquake
# triggered --> tsunami
# shook --> earthquake
# shook --> earthquake
# appeared --> earthquake
# shook --> earthquake
# loosened --> earthquake
# induced --> earthquake
# [('earthquake --> shook', 3),
#  ('tsunami --> related', 2),
#  ('earthquake --> loosened', 2),
#  ('earthquake --> REJECTEDAn', 1),
#  ('earthquake --> caused', 1),
#  ('earthquake --> mentions', 1),
#  ('tsunami --> triggered', 1),
#  ('earthquake --> appeared', 1),
#  ('earthquake --> induced', 1)]

# %%
"""
4.4 DISASTER and GPE/LOC
GPE Found: Deccan volcanism and the Chicxulub impact, earthquake shook Mexico City
LOC Found: earthquake shook the New England coast, eruption of Mount St. Helens, River Valley was raised by volcanic debris,
Old Testament mentions an earthquake that occurred in the days of King Uzziah
"""

matcher= Matcher(nlp.vocab)
pattern= [{"ENT_TYPE": "LOC"}, {"OP": "?"}, {"OP": "?"}, {"OP": "?"}, {"OP": "?"}, {"ENT_TYPE": "DISASTER"}, {"OP": "?"}, {"OP": "?"}, {"OP": "?"}]

matcher.add("DISPLAC", [pattern])

all_placs= []
for doc in docs:
    mat= nlp(doc['doc'])
    matches= matcher(mat)
    
    if matches:
        print(doc['title'])
        for match_id, start, end in matches:
            all_placs.append(mat[start:end].text)
            
        print([mat[start:end].text for match_id, start, end in matches])
        print()

elems2= ['earthquake', 'earthquakes', 'tsunami', 'tsunamis', 'volcanic', 'eruption', 'volcanism']

fina= []
for plac in all_placs:
    for d in elems2:
        if d in plac:
            fina.append(plac)
            
FreqDist(fina).most_common()
# Out:
# The Paleozoic Rock Record: A Broad Overview of Features and Trends–by Ronny Nalin
# ['America and Europe', 'America and Europe contain', 'North America and Europe', 'North America and Europe contain', 'America and Europe contain a', 'North America and Europe contain a', 'America and Europe contain a cluster', 'North America and Europe contain a cluster']
#
# The Role of Catastrophes in Scientific Thinking–by Ariel A. Roth
# ['Europe and Africa', 'Europe and Africa.', 'Europe and Africa. Its', 'Europe and Africa. Its effects', 'Nyos in Cameroon', 'Nyos in Cameroon.', 'Lake Nyos in Cameroon', 'Lake Nyos in Cameroon.', 'Nyos in Cameroon. The', 'Lake Nyos in Cameroon. The', 'Nyos in Cameroon. The cloud', 'Lake Nyos in Cameroon. The cloud']
#
# How Do Plate Tectonics Relate to the Bible?–by Benjamin L. Clausen
# ['Testament mentions an earthquake', 'Testament mentions an earthquake that', 'Old Testament mentions an earthquake', 'Old Testament mentions an earthquake that', 'Testament mentions an earthquake that occurred', 'Old Testament mentions an earthquake that occurred', 'Testament mentions an earthquake that occurred in', 'Old Testament mentions an earthquake that occurred in', 'St. Helens', 'St. Helens .Time', 'Mt. St. Helens', 'Mt. St. Helens .Time', 'St. Helens .Time.', 'Mt. St. Helens .Time.', 'St. Helens .Time. At', 'Mt. St. Helens .Time. At']
#
# A Note on the Pre-Flood/Flood Boundary in the Grand Canyon–by Kurt P. Wise, Andrew Snelling
# ['Formation.Stromatolites', 'Formation.Stromatolites have', 'Sixtymile Formation.Stromatolites', 'Sixtymile Formation.Stromatolites have', 'Formation.Stromatolites have been', 'Sixtymile Formation.Stromatolites have been', 'Formation.Stromatolites have been reported', 'Sixtymile Formation.Stromatolites have been reported', 'Canyon, the Antediluvian', 'Canyon, the Antediluvian expression', 'Grand Canyon, the Antediluvian', 'Grand Canyon, the Antediluvian expression', 'Canyon, the Antediluvian expression of', 'Grand Canyon, the Antediluvian expression of', 'Canyon, the Antediluvian expression of the', 'Grand Canyon, the Antediluvian expression of the', 'Canyon, the Antediluvian expression of the Butte', 'Grand Canyon, the Antediluvian expression of the Butte']
#
# Annotations from the Literature
# ['Nyos in 1986. Methane', 'Nyos in 1986. Methane is', 'Lake Nyos in 1986. Methane', 'Lake Nyos in 1986. Methane is', 'Nyos in 1986. Methane is typically', 'Lake Nyos in 1986. Methane is typically', 'Nyos in 1986. Methane is typically depleted', 'Lake Nyos in 1986. Methane is typically depleted', 'Sea dry out during the Miocene', 'Sea dry out during the Miocene?', 'Sea dry out during the Miocene? A', 'Sea dry out during the Miocene? A reassessment', 'MJ, Soejono RP, Jatmiko', 'MJ, Soejono RP, Jatmiko,', 'MJ, Soejono RP, Jatmiko, Saptomo', 'MJ, Soejono RP, Jatmiko, Saptomo EW', 'GD, Due RA, Hobbs', 'GD, Due RA, Hobbs DR', 'GD, Due RA, Hobbs DR,', 'GD, Due RA, Hobbs DR, Moore', 'Europe and Asia', 'Europe and Asia are', 'Europe and Asia are thought', 'Europe and Asia are thought to']
#
# The Miocene/Pleistocene Contact in the Columbia Basin–by Harold G. Coffin
# ['Idaho and Western Montana', 'Idaho and Western Montana removed', 'Northern Idaho and Western Montana', 'Northern Idaho and Western Montana removed', 'Idaho and Western Montana removed the', 'Northern Idaho and Western Montana removed the', 'Idaho and Western Montana removed the loess', 'Northern Idaho and Western Montana removed the loess', 'Mountains, Wanapum', 'Mountains, Wanapum,', 'Saddle Mountains, Wanapum', 'Saddle Mountains, Wanapum,', 'Mountains, Wanapum, and', 'Saddle Mountains, Wanapum, and', 'Mountains, Wanapum, and Grande', 'Saddle Mountains, Wanapum, and Grande', 'Mountains, Wanapum, and Grande Ronde', 'Saddle Mountains, Wanapum, and Grande Ronde']
#
# Annotations from the Literature–by L. James Gibson
# ['Cristobal and Espanola', 'Cristobal and Espanola,', 'San Cristobal and Espanola', 'San Cristobal and Espanola,', 'Cristobal and Espanola, which', 'San Cristobal and Espanola, which', 'Cristobal and Espanola, which are', 'San Cristobal and Espanola, which are', 'America. Extinction of the Eurasian', 'America. Extinction of the Eurasian and', 'America. Extinction of the Eurasian and North', 'America. Extinction of the Eurasian and North American', 'Tanganyika has 49', 'Tanganyika has 49 endemic', 'Lake Tanganyika has 49', 'Lake Tanganyika has 49 endemic', 'Tanganyika has 49 endemic genera', 'Lake Tanganyika has 49 endemic genera', 'Tanganyika has 49 endemic genera of', 'Lake Tanganyika has 49 endemic genera of', 'Tanganyika has 49 endemic genera of cichlid', 'Lake Tanganyika has 49 endemic genera of cichlid']
#
# Local Catastrophes, or a Worldwide Deluge?–by L. James Gibson
# ['Sea, scattering throughout Europe', 'Sea, scattering throughout Europe and', 'Black Sea, scattering throughout Europe', 'Black Sea, scattering throughout Europe and', 'Sea, scattering throughout Europe and southwestern', 'Black Sea, scattering throughout Europe and southwestern', 'Sea, scattering throughout Europe and southwestern Asia', 'Black Sea, scattering throughout Europe and southwestern Asia', 'Sea and the Mediterranean', 'Sea and the Mediterranean,', 'Black Sea and the Mediterranean', 'Black Sea and the Mediterranean,', 'Sea and the Mediterranean, and', 'Black Sea and the Mediterranean, and', 'Sea and the Mediterranean, and converting', 'Black Sea and the Mediterranean, and converting']
#
# Geological Society of America Meeting–by Kurt P. Wise, Arthur V. Chadwick
# ['Kingdom repairs on the Sphinx', 'Kingdom repairs on the Sphinx and', 'Old Kingdom repairs on the Sphinx', 'Old Kingdom repairs on the Sphinx and', 'Kingdom repairs on the Sphinx and early', 'Old Kingdom repairs on the Sphinx and early', 'Kingdom repairs on the Sphinx and early Old', 'Old Kingdom repairs on the Sphinx and early Old']
#
# The Yellowstone Fossil “Forests"–by Harold G. Coffin
# ['Park in Wyoming and Montana', 'Park in Wyoming and Montana are', 'National Park in Wyoming and Montana', 'National Park in Wyoming and Montana are', 'Park in Wyoming and Montana are perhaps', 'National Park in Wyoming and Montana are perhaps', 'Park in Wyoming and Montana are perhaps the', 'National Park in Wyoming and Montana are perhaps the', 'California mature redwood forest revealed 135', 'California mature redwood forest revealed 135 sequoia', 'California mature redwood forest revealed 135 sequoia cones', 'California mature redwood forest revealed 135 sequoia cones and', 'Creek area. Nine', 'Creek area. Nine bands', 'Specimen Creek area. Nine', 'Specimen Creek area. Nine bands', 'Creek area. Nine bands of', 'Specimen Creek area. Nine bands of', 'Creek area. Nine bands of clay', 'Specimen Creek area. Nine bands of clay', 'Creek area. Nine bands of clay that', 'Specimen Creek area. Nine bands of clay that', 'St. Helens', 'St. Helens did', 'Mount St. Helens', 'Mount St. Helens did', 'St. Helens did not', 'Mount St. Helens did not', 'St. Helens did not have', 'Mount St. Helens did not have', 'St. Helens', 'St. Helens in', 'Mount St. Helens', 'Mount St. Helens in', 'St. Helens in the', 'Mount St. Helens in the', 'St. Helens in the state', 'Mount St. Helens in the state', 'St. Helens', 'St. Helens,', 'Mount St. Helens', 'Mount St. Helens,', 'St. Helens, Spirit', 'Mount St. Helens, Spirit', 'St. Helens, Spirit Lake', 'Mount St. Helens, Spirit Lake', 'River Valley was raised by volcanic', 'River Valley was raised by volcanic debris', 'River Valley was raised by volcanic debris.', 'River Valley was raised by volcanic debris. This', 'St. Helens', 'St. Helens tore', 'Mount St. Helens', 'Mount St. Helens tore', 'St. Helens tore thousands', 'Mount St. Helens tore thousands', 'St. Helens tore thousands of', 'Mount St. Helens tore thousands of', 'St. Helens', 'St. Helens provides', 'Mount St. Helens', 'Mount St. Helens provides', 'St. Helens provides a', 'Mount St. Helens provides a', 'St. Helens provides a model', 'Mount St. Helens provides a model']
#
# Challenging the Creed: Doubts About Plate Tectonics?–by L. James Gibson
# ['Europe, African', 'Europe, African marginal', 'America and Europe, African', 'America and Europe, African marginal', 'North America and Europe, African', 'North America and Europe, African marginal', 'Europe, African marginal embayments', 'America and Europe, African marginal embayments', 'North America and Europe, African marginal embayments', 'Europe, African marginal embayments,', 'America and Europe, African marginal embayments,', 'North America and Europe, African marginal embayments,', 'Europe, African marginal embayments, and', 'America and Europe, African marginal embayments, and']
# An Alternative Explanation of Oceanic Magnetic Anomaly Patterns–by Norm Smith, Jane Smith
# ['Europe and Africa', 'Europe and Africa,', 'Europe and Africa, the', 'Europe and Africa, the coastlines']
#
# Annotations from the Literature
# ['Project site 612', 'Project site 612 bolide', 'Drilling Project site 612', 'Drilling Project site 612 bolide', 'Sea Drilling Project site 612', 'Sea Drilling Project site 612 bolide', 'Deep Sea Drilling Project site 612', 'Deep Sea Drilling Project site 612 bolide', 'Project site 612 bolide event', 'Drilling Project site 612 bolide event', 'Sea Drilling Project site 612 bolide event', 'Deep Sea Drilling Project site 612 bolide event', 'Project site 612 bolide event:', 'Drilling Project site 612 bolide event:', 'Sea Drilling Project site 612 bolide event:', 'Deep Sea Drilling Project site 612 bolide event:', 'America and Europe', 'America and Europe:', 'North America and Europe', 'North America and Europe:', 'America and Europe: biological', 'North America and Europe: biological', 'America and Europe: biological,', 'North America and Europe: biological,', 'America and Europe', 'America and Europe have', 'North America and Europe', 'North America and Europe have', 'America and Europe have been', 'North America and Europe have been', 'America and Europe have been identified', 'North America and Europe have been identified', 'America and northwestern Europe', 'America and northwestern Europe.', 'North America and northwestern Europe', 'North America and northwestern Europe.', 'America and northwestern Europe. The', 'North America and northwestern Europe. The', 'America and northwestern Europe. The eruption', 'North America and northwestern Europe. The eruption', 'Europe and Asia', 'Europe and Asia.', 'Europe and Asia. This', 'Europe and Asia. This has']
#
# Clastic Pipes and Dikes in Kodachrome Basin–by Ariel A. Roth
# ['Butte member of the Entrada', 'Butte member of the Entrada .', 'Gunsight Butte member of the Entrada', 'Gunsight Butte member of the Entrada .', 'Butte member of the Entrada . One', 'Gunsight Butte member of the Entrada . One', 'Butte member of the Entrada . One intrudes', 'Gunsight Butte member of the Entrada . One intrudes']
#
# A Post-Flood Ice-Age Model Can Account for Quaternary Features–by Michael J. Oard
# ['States Lake Bonneville was 17', 'States Lake Bonneville was 17 times', 'United States Lake Bonneville was 17', 'United States Lake Bonneville was 17 times', 'States Lake Bonneville was 17 times larger', 'United States Lake Bonneville was 17 times larger', 'States Lake Bonneville was 17 times larger and', 'United States Lake Bonneville was 17 times larger and', 'States Lake Bonneville was 17 times larger and 285', 'America  and Asia', 'America  and Asia and', 'North America  and Asia', 'North America  and Asia and', 'America  and Asia and off', 'North America  and Asia and off', 'America  and Asia and off the', 'North America  and Asia and off the', 'States. Heavy', 'States. Heavy precipitation', 'United States. Heavy', 'United States. Heavy precipitation', 'States. Heavy precipitation would', 'United States. Heavy precipitation would', 'States. Heavy precipitation would then', 'United States. Heavy precipitation would then', 'Hemisphere and 1880 m over Antarctica', 'Hemisphere and 1880 m over Antarctica .My', 'Hemisphere and 1880 m over Antarctica .My estimates', 'Hemisphere and 1880 m over Antarctica .My estimates for']
#
# Those Gaps in the Sedimentary Layers–by Ariel A. Roth
# ['Canyon, the Ordovician', 'Canyon, the Ordovician and', 'Grand Canyon, the Ordovician', 'Grand Canyon, the Ordovician and', 'Canyon, the Ordovician and Silurian', 'Grand Canyon, the Ordovician and Silurian', 'Canyon, the Ordovician and Silurian portions', 'Grand Canyon, the Ordovician and Silurian portions', 'Canyon, the Ordovician and Silurian portions of', 'Grand Canyon, the Ordovician and Silurian portions of', 'Canyon, the Ordovician and Silurian portions of the', 'States in 10 Ma', 'States in 10 Ma or', 'United States in 10 Ma', 'United States in 10 Ma or', 'States in 10 Ma or less', 'United States in 10 Ma or less', 'States in 10 Ma or less.', 'United States in 10 Ma or less.', 'States in 10 Ma or less.It', 'United States in 10 Ma or less.It', 'Island and the surrounding Gulfs', 'Island and the surrounding Gulfs region', 'Kangaroo Island and the surrounding Gulfs', 'Kangaroo Island and the surrounding Gulfs region', 'Island and the surrounding Gulfs region in', 'Kangaroo Island and the surrounding Gulfs region in', 'Island and the surrounding Gulfs region in South', 'Kangaroo Island and the surrounding Gulfs region in South']
#
# Some Questions about Geochronology–by Ariel A. Roth
# ['St. Helens', 'St. Helens  ', 'Mt. St. Helens', 'Mt. St. Helens  ', 'St. Helens  1', 'Mt. St. Helens  1', 'St. Helens  1 km3', 'Mt. St. Helens  1 km3', 'St. Helens', 'St. Helens ejected', 'Mt. St. Helens', 'Mt. St. Helens ejected', 'St. Helens ejected a', 'Mt. St. Helens ejected a', 'St. Helens ejected a significant', 'Mt. St. Helens ejected a significant']
#
# Rapid Erosion at Mount St. Helens–by Steven A. Austin
# ['St. Helens', 'St. Helens are', 'Mount St. Helens', 'Mount St. Helens are', 'St. Helens are compared', 'Mount St. Helens are compared', 'St. Helens are compared to', 'Mount St. Helens are compared to', 'St. Helens', 'St. Helens volcano', 'Mount St. Helens', 'Mount St. Helens volcano', 'St. Helens volcano in', 'Mount St. Helens volcano in', 'St. Helens volcano in Washington', 'Mount St. Helens volcano in Washington', 'St. Helens', 'St. Helens are', 'Mount St. Helens', 'Mount St. Helens are', 'St. Helens are not', 'Mount St. Helens are not', 'St. Helens are not unique', 'Mount St. Helens are not unique', 'St. Helens', 'St. Helens.', 'Mount St. Helens', 'Mount St. Helens.', 'St. Helens. On', 'Mount St. Helens. On', 'St. Helens. On the', 'Mount St. Helens. On the', 'St. Helens', 'St. Helens and', 'Mount St. Helens', 'Mount St. Helens and', 'St. Helens and elsewhere', 'Mount St. Helens and elsewhere', 'St. Helens and elsewhere causes', 'Mount St. Helens and elsewhere causes', 'St. Helens', 'St. Helens was', 'Mount St. Helens', 'Mount St. Helens was', 'St. Helens was noticeably', 'Mount St. Helens was noticeably', 'St. Helens was noticeably discontinuous', 'Mount St. Helens was noticeably discontinuous', 'St. Helens', 'St. Helens,', 'Mount St. Helens', 'Mount St. Helens,', 'St. Helens, Washington', 'Mount St. Helens, Washington', 'St. Helens, Washington.', 'Mount St. Helens, Washington.']
#
# Paleomagnetism II–by Ivan E. Rouse
# ['St. Helens', 'St. Helens,', 'Mount St. Helens', 'Mount St. Helens,', 'St. Helens, deposited', 'Mount St. Helens, deposited', 'St. Helens, deposited from', 'Mount St. Helens, deposited from', "Earth's FieldThe", "Earth's FieldThe rather", "Earth's FieldThe rather unexpected", "Earth's FieldThe rather unexpected idea"]
#
# Mount St. Helens and Spirit Lake–by Harold G. Coffin
# ['St. Helens', 'St. Helens has', 'Mount St. Helens', 'Mount St. Helens has', 'St. Helens has become', 'Mount St. Helens has become', 'St. Helens has become a', 'Mount St. Helens has become a', 'St. Helens', 'St. Helens.', 'Mount St. Helens', 'Mount St. Helens.', 'St. Helens. In', 'Mount St. Helens. In', 'St. Helens. In addition', 'Mount St. Helens. In addition', 'St. Helens', 'St. Helens erupted', 'Mount St. Helens', 'Mount St. Helens erupted', 'St. Helens erupted with', 'Mount St. Helens erupted with', 'St. Helens erupted with a', 'Mount St. Helens erupted with a', 'Flow and Stump TransportationThe', 'Flow and Stump TransportationThe debris', 'Debris Flow and Stump TransportationThe', 'Debris Flow and Stump TransportationThe debris', 'Flow and Stump TransportationThe debris flow', 'Debris Flow and Stump TransportationThe debris flow', 'Flow and Stump TransportationThe debris flow,', 'Debris Flow and Stump TransportationThe debris flow,', 'St. Helens', 'St. Helens.', 'Mount St. Helens', 'Mount St. Helens.', 'St. Helens.Between', 'Mount St. Helens.Between', 'St. Helens.Between the', 'Mount St. Helens.Between the', 'St. Helens', 'St. Helens.', 'Mount St. Helens', 'Mount St. Helens.', 'St. Helens. Here', 'Mount St. Helens. Here', 'St. Helens. Here is', 'Mount St. Helens. Here is', 'St. Helens', 'St. Helens,', 'Mount St. Helens', 'Mount St. Helens,', 'St. Helens, with', 'Mount St. Helens, with', 'St. Helens, with its', 'Mount St. Helens, with its']
# Paleomagnetism I–by Ivan E. Rouse
# ['Earth as MagnetMost', 'Earth as MagnetMost individuals', 'Earth as MagnetMost individuals are', 'Earth as MagnetMost individuals are aware', 'St. Helens', 'St. Helens ,', 'Mount St. Helens', 'Mount St. Helens ,', 'St. Helens , and', 'Mount St. Helens , and', 'St. Helens , and it', 'Mount St. Helens , and it']
#
# Megabreccias: Evidence for Catastrophism–by Arthur V. Chadwick
# ['Banks slump of 1929', 'Banks slump of 1929,', 'Grand Banks slump of 1929', 'Grand Banks slump of 1929,', 'Banks slump of 1929, is', 'Grand Banks slump of 1929, is', 'Banks slump of 1929, is historical', 'Grand Banks slump of 1929, is historical']
#
# Old Traditions on Trial–by Ariel A. Roth
# ['of Africa', 'of Africa.', 'Mountains of Africa', 'Mountains of Africa.', 'Atlas Mountains of Africa', 'Atlas Mountains of Africa.', 'of Africa. He', 'Mountains of Africa. He', 'Atlas Mountains of Africa. He', 'of Africa. He generally', 'Mountains of Africa. He generally', 'Atlas Mountains of Africa. He generally']
# [('Testament mentions an earthquake', 1),
#  ('Testament mentions an earthquake that', 1),
#  ('Old Testament mentions an earthquake', 1),
#  ('Old Testament mentions an earthquake that', 1),
#  ('Testament mentions an earthquake that occurred', 1),
#  ('Old Testament mentions an earthquake that occurred', 1),
#  ('Testament mentions an earthquake that occurred in', 1),
#  ('Old Testament mentions an earthquake that occurred in', 1),
#  ('River Valley was raised by volcanic', 1),
#  ('River Valley was raised by volcanic debris', 1),
#  ('River Valley was raised by volcanic debris.', 1),
#  ('River Valley was raised by volcanic debris. This', 1),
#  ('America and northwestern Europe. The eruption', 1),
#  ('North America and northwestern Europe. The eruption', 1)]

# %%
"""
5 Spark Clustering
Cluster 1: Flood
Cluster 2: Fossil
Cluster 3: Magnetism
"""

import findspark
findspark.init()
import pyspark
#from pyspark.sql import SQLContext
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('Clustering').getOrCreate()
sc = pyspark.SparkContext(appName="Clustering")
#sqlContext = SQLContext(sc)

# %%
sc.stop()
spark.stop()

# %%
#Create dataframe with docs
wordsData = spark.createDataFrame([
    (docs[0]['doc'].split(" "), ),
    (docs[1]['doc'].split(" "), ),
    (docs[2]['doc'].split(" "), ),
    (docs[3]['doc'].split(" "), ),
    (docs[4]['doc'].split(" "), ),
    (docs[5]['doc'].split(" "), ),
    (docs[6]['doc'].split(" "), ),
    (docs[7]['doc'].split(" "), ),
    (docs[8]['doc'].split(" "), ),
    (docs[9]['doc'].split(" "), ),
    (docs[10]['doc'].split(" "), ),
    (docs[11]['doc'].split(" "), ),
    (docs[12]['doc'].split(" "), ),
    (docs[13]['doc'].split(" "), ),
    (docs[14]['doc'].split(" "), ),
    (docs[15]['doc'].split(" "), ),
    (docs[16]['doc'].split(" "), ),
    (docs[17]['doc'].split(" "), ),
    (docs[18]['doc'].split(" "), ),
    (docs[19]['doc'].split(" "), ),
    (docs[20]['doc'].split(" "), ),
    (docs[21]['doc'].split(" "), ),
    (docs[22]['doc'].split(" "), ),
    (docs[23]['doc'].split(" "), ),
    (docs[24]['doc'].split(" "), ),
    (docs[25]['doc'].split(" "), ),
    (docs[26]['doc'].split(" "), ),
    (docs[27]['doc'].split(" "), ),
    (docs[28]['doc'].split(" "), ),
    (docs[29]['doc'].split(" "), ),
    (docs[30]['doc'].split(" "), ),
    (docs[31]['doc'].split(" "), ),
    (docs[32]['doc'].split(" "), ),
    (docs[33]['doc'].split(" "), ),
    (docs[34]['doc'].split(" "), ),
    (docs[35]['doc'].split(" "), ),
    (docs[36]['doc'].split(" "), ),
    (docs[37]['doc'].split(" "), ),
    (docs[38]['doc'].split(" "), ),
    (docs[39]['doc'].split(" "), ),
    (docs[40]['doc'].split(" "), ),
    (docs[41]['doc'].split(" "), ),
    (docs[42]['doc'].split(" "), ),
    (docs[43]['doc'].split(" "), ),
    (docs[44]['doc'].split(" "), ),
    (docs[45]['doc'].split(" "), ),
    (docs[46]['doc'].split(" "), ),
    (docs[47]['doc'].split(" "), ),
    (docs[48]['doc'].split(" "), ),
    (docs[49]['doc'].split(" "), ),
    (docs[40]['doc'].split(" "), ),
    (docs[51]['doc'].split(" "), ),
    (docs[52]['doc'].split(" "), ),
    (docs[53]['doc'].split(" "), ),
    (docs[54]['doc'].split(" "), ),
    (docs[55]['doc'].split(" "), ),
    (docs[56]['doc'].split(" "), ),
    (docs[57]['doc'].split(" "), ),
    (docs[58]['doc'].split(" "), ),
    (docs[59]['doc'].split(" "), ),
    (docs[60]['doc'].split(" "), )
], ["tokens"])

# %%
#Create dataframe with titles
titles = spark.createDataFrame([
    (docs[0]['title'], ),
    (docs[1]['title'], ),
    (docs[2]['title'], ),
    (docs[3]['title'], ),
    (docs[4]['title'], ),
    (docs[5]['title'], ),
    (docs[6]['title'], ),
    (docs[7]['title'], ),
    (docs[8]['title'], ),
    (docs[9]['title'], ),
    (docs[10]['title'], ),
    (docs[11]['title'], ),
    (docs[12]['title'], ),
    (docs[13]['title'], ),
    (docs[14]['title'], ),
    (docs[15]['title'], ),
    (docs[16]['title'], ),
    (docs[17]['title'], ),
    (docs[18]['title'], ),
    (docs[19]['title'], ),
    (docs[20]['title'], ),
    (docs[21]['title'], ),
    (docs[22]['title'], ),
    (docs[23]['title'], ),
    (docs[24]['title'], ),
    (docs[25]['title'], ),
    (docs[26]['title'], ),
    (docs[27]['title'], ),
    (docs[28]['title'], ),
    (docs[29]['title'], ),
    (docs[30]['title'], ),
    (docs[31]['title'], ),
    (docs[32]['title'], ),
    (docs[33]['title'], ),
    (docs[34]['title'], ),
    (docs[35]['title'], ),
    (docs[36]['title'], ),
    (docs[37]['title'], ),
    (docs[38]['title'], ),
    (docs[39]['title'], ),
    (docs[40]['title'], ),
    (docs[41]['title'], ),
    (docs[42]['title'], ),
    (docs[43]['title'], ),
    (docs[44]['title'], ),
    (docs[45]['title'], ),
    (docs[46]['title'], ),
    (docs[47]['title'], ),
    (docs[48]['title'], ),
    (docs[49]['title'], ),
    (docs[50]['title'], ),
    (docs[51]['title'], ),
    (docs[52]['title'], ),
    (docs[53]['title'], ),
    (docs[54]['title'], ),
    (docs[55]['title'], ),
    (docs[56]['title'], ),
    (docs[57]['title'], ),
    (docs[58]['title'], ),
    (docs[59]['title'], ),
    (docs[60]['title'], )
], ["title"])

# %%
# Word2Vec
from pyspark.ml.feature import Word2Vec
word2Vec = Word2Vec(vectorSize=80, minCount=0, maxIter=10, inputCol="tokens", outputCol="features")
model = word2Vec.fit(wordsData)
result = model.transform(wordsData)

# %%
#Get vectors
li = [row[0] for row in result.select("features").collect()]
alls= []
for i in li:
    al= []
    for j in i:
        al.append(j)
    alls.append(al)

# %%
from sklearn.cluster import KMeans

#Apply K Means
kmeans = KMeans(n_clusters=3).fit(alls)
print('SSE:', kmeans.inertia_)

labels = kmeans.predict(alls)
df = spark.createDataFrame([(int(value),) for value in labels], ['label'])
# Out:
# SSE: 4.538877208643603

# %%
from pyspark.sql.functions import monotonically_increasing_id

titles = titles.withColumn("id", monotonically_increasing_id())
df = df.withColumn("id", monotonically_increasing_id())

df3 = titles.join(df, "id", "outer").drop("id")

# %%
#Get by cluster
c0= df3.filter(df3.label == 0).select(df3.title)
c1= df3.filter(df3.label == 1).select(df3.title)
c2= df3.filter(df3.label == 2).select(df3.title)

# %%
def getLabels(c):
    li0= [row for row in c.select("title").collect()]
    alls0= []
    for i in li0:
        al= []
        for j in i:
            al.append(j)
        alls0.append(al)
    #Flat list
    alls0= [item for sublist in alls0 for item in sublist]
    #-by
    alls0= [a.split('by')[0][:-1] for a in alls0]
    
    return alls0

print(getLabels(c0))
print(getLabels(c1))
print(getLabels(c2))
# Out:
# ['The Enigmatic Geologic Column', 'Can Science and Religion Work Together?', 'The Role of Catastrophes in Scientific Thinking', 'Wholistic Geology: Geology Before, During, and After the Biblical Flood', 'The Precambrian: Part 3 of 3', 'Glaciations and the Geologic Record', 'The Mexico Earthquake', 'The Paleozoic Rock Record: A Broad Overview of Features and Trends', 'How Do Plate Tectonics Relate to the Bible?', 'What Is the Evidence for a Large Asteroid Impact at the Cretaceous-Paleogene (K-Pg) Boundary?', 'Local Catastrophes, or a Worldwide Deluge?', 'Catastrophism: Discussion of Its Current Status in Geology, and a Prediction', 'Was There A Great Genesis Flood?', 'A Catastrophe With an Impact', 'A Note on the Pre-Flood/Flood Boundary in the Grand Canyon', 'Catastrophic Earth Science: A Realistic Science', 'The Grand Staircase: a Case Study in Scientific Thinking from a Biblical Worldview', 'Those Gaps in the Sedimentary Layers', 'The Geological Story Told', 'Megabreccia and Catastrophe', 'Climbing Up and Down Through the Fossil Record']
# ['Annotations from the Literatur', 'Annotations from the Literatur', 'The Miocene/Pleistocene Contact in the Columbia Basin', 'Annotations from the Literatur', 'The Intrigue of the Questions about the Bridgewater “Fossil Forest,” Victoria, Australia', 'Foreword', 'Clastic Pipes and Dikes in Kodachrome Basin', 'Unique Enigmatic Helium', 'Annotations from the Literatur', 'The Canyon of Canyons', 'Geological Society of America Meeting', 'Annotations from the Literatur', 'Examining Radiohalos (Review of Creation’s Tiny Mystery)', 'The Yellowstone Fossil “Forests"', 'Annotations from the Literatur', 'False Fossils', 'Incomplete Ecosystems', 'The Nature of Evidence, as Illustrated', 'The Implications of the Oklo Phenomenon on the Constancy of Radiometric Decay Rates', 'Annotations from the Literature', 'Annotations from the Literatur']
# ['Dinosaurs and Dust', 'The El Niño Event', 'Paleomagnetism I', 'Paleomagnetism II', 'The Little Ice Age', 'The Tunguska Explosion of 1908', 'An Alternative Explanation of Oceanic Magnetic Anomaly Patterns', 'Are Millions of Years Required to Produce Biogenic Sediments in the Deep Ocean?', 'Rapid Bedrock Incision', 'Mount St. Helens and Spirit Lake', 'A Venture in Unorthodoxy', 'Geomagnetic Intensity Decay: The Fit of the Data', 'A Post-Flood Ice-Age Model Can Account for Quaternary Features', 'Some Questions about Geochronology', "NASA's Next Interplanetary Mission", "Reversal of Earth's Magnetic Field", 'Expanding Earth?', 'Challenging the Creed: Doubts About Plate Tectonics?', 'Rapid Erosion at Mount St. Helens']

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

stopwords = set(STOPWORDS)
stopwords.update(["Annotations", "from", "Literatur"])

#Cluster 1
unique_string = (" ").join(getLabels(c0))
wordcloud = WordCloud(stopwords=stopwords, width = 1000, height = 500).generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
plt.close()

# %%
#Cluster 2
unique_string = (" ").join(getLabels(c1))
wordcloud = WordCloud(stopwords=stopwords, width = 1000, height = 500).generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
plt.close()

# %%
#Cluster 3
unique_string = (" ").join(getLabels(c2))
wordcloud = WordCloud(stopwords=stopwords, width = 1000, height = 500).generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
plt.close()
